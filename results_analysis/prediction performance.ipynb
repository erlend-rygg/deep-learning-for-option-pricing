# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
from sklearn.metrics import mean_squared_error

# %%
model_names = ['LSTM-MLP', 'Heston', 'IV', 'GARCH', 'Rolling']
columns = ['Option_ID', 'Quote_date', 'Price', 'Underlying_last', 'Strike', 'TTM', 'Expiry_date', 'R']

df = pd.read_csv('../data/results/combined_predictions2.csv')
df['Expiry_date'] = pd.to_datetime(df['Quote_date']) + pd.to_timedelta(df['TTM']*365, unit='D')
df["Option_ID"] = df["Expiry_date"].astype(str) + "-" + df["Strike"].astype(str)
df = df[columns + model_names]
df = df.sort_values(by=['Strike', 'Expiry_date', 'Quote_date'])
print(df.head(3))
df.info()
# Out:
#            Option_ID  Quote_date    Price  Underlying_last  Strike       TTM  \
# 0  2017-12-22-2425.0  2017-11-24  178.250          2602.42  2425.0  0.076712
# 1  2017-12-26-2150.0  2017-11-24  451.595          2602.42  2150.0  0.087671
# 2  2018-01-05-2170.0  2017-11-24  432.895          2602.42  2170.0  0.115068
#
#   Expiry_date         R   LSTM-MLP      Heston          IV       GARCH  \
# 0  2017-12-22  0.011400  181.22504  180.125992  182.984386  179.561340
# 1  2017-12-26  0.011454  452.85504  453.536094  460.091426  454.577919
# 2  2018-01-05  0.011730  433.30730  434.552391  438.113114  435.346946
#
#       Rolling
# 0  179.539789
# 1  454.577919
# 2  435.346946
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10539487 entries, 0 to 10539486
# Data columns (total 13 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Option_ID        object
#  1   Quote_date       object
#  2   Price            float64
#  3   Underlying_last  float64
#  4   Strike           float64
#  5   TTM              float64
#  6   Expiry_date      datetime64[ns]
#  7   R                float64
#  8   LSTM-MLP         float64
#  9   Heston           float64
#  10  IV               float64
#  11  GARCH            float64
#  12  Rolling          float64
# dtypes: datetime64[ns](1), float64(10), object(2)
# memory usage: 1.0+ GB

# %%
# Assuming df is your DataFrame
df_p = df.copy()

df_p = df_p.rename(columns={'LSTM-MLP': 'Prediction'})

# Calculate the actual change in market price
df_p['actual_change'] = df_p.groupby(['Strike', 'Expiry_date'])['Price'].diff().shift(-1)

# Calculate the predicted change in market price
df_p['predicted_change'] = df_p['Prediction'] - df['Price']

# Determine if the actual and predicted changes are in the same direction
df_p['same_direction'] = df_p['actual_change'] * df_p['predicted_change'] > 0

# Drop the last row of each group as it has no tomorrow's data to compare with
df_p = df_p[~df_p.groupby(['Strike', 'Expiry_date'])['Price'].transform(lambda x: x.index == x.index[-1])]

# Calculate the percentage of times the prediction was correct
percentage_correct = df_p['same_direction'].mean() * 100

print(f"The model correctly predicted the direction of the price change {percentage_correct:.2f}% of the time.")
# Out:
# The model correctly predicted the direction of the price change 49.99% of the time.

# %%
# Assuming df_a is your DataFrame
df_a = df.copy()
df_a = df_a.rename(columns={'LSTM-MLP': 'Prediction'})
df_a['Relative_pricing_error'] = (df_a['Prediction'] - df_a['Price']) / df_a['Price']

#df_a = df_a[df_a['Relative_pricing_error'] <= -0.1]

# Calculate the actual change in market price for different days ahead
days_ahead = [i for i in range(1, 21)]
for days in days_ahead:
    df_a[f'Actual_change_{days}'] = df_a.groupby(['Strike', 'Expiry_date'])['Price'].shift(-days) - df_a['Price']

# Calculate the predicted change in market price
df_a['Predicted_change'] = df_a['Prediction'] - df_a['Price']

# Determine if the actual and predicted changes are in the same direction
for days in days_ahead:
    df_a[f'Same_direction_{days}'] = df_a[f'Actual_change_{days}'] * df_a['Predicted_change'] > 0

# Calculate the percentage of times the prediction was correct
for days in days_ahead:
    # Only consider rows where we have enough data in the future
    df_a = df_a.dropna(subset=[f'Actual_change_{days}', f'Same_direction_{days}'])
    percentage_correct = df_a[f'Same_direction_{days}'].mean() * 100
    print(f"For a {days}-day horizon, the model correctly predicted the direction of the price change {percentage_correct:.2f}% of the time.")
# Out:
# For a 1-day horizon, the model correctly predicted the direction of the price change 48.62% of the time.
# For a 2-day horizon, the model correctly predicted the direction of the price change 48.56% of the time.
# For a 3-day horizon, the model correctly predicted the direction of the price change 48.55% of the time.
# For a 4-day horizon, the model correctly predicted the direction of the price change 48.54% of the time.
# For a 5-day horizon, the model correctly predicted the direction of the price change 48.52% of the time.
# For a 6-day horizon, the model correctly predicted the direction of the price change 48.51% of the time.
# For a 7-day horizon, the model correctly predicted the direction of the price change 48.51% of the time.
# For a 8-day horizon, the model correctly predicted the direction of the price change 48.52% of the time.
# For a 9-day horizon, the model correctly predicted the direction of the price change 48.50% of the time.
# For a 10-day horizon, the model correctly predicted the direction of the price change 48.50% of the time.
# For a 11-day horizon, the model correctly predicted the direction of the price change 48.52% of the time.
# For a 12-day horizon, the model correctly predicted the direction of the price change 48.51% of the time.
# For a 13-day horizon, the model correctly predicted the direction of the price change 48.45% of the time.
# For a 14-day horizon, the model correctly predicted the direction of the price change 48.46% of the time.
# For a 15-day horizon, the model correctly predicted the direction of the price change 48.44% of the time.
# For a 16-day horizon, the model correctly predicted the direction of the price change 48.46% of the time.
# For a 17-day horizon, the model correctly predicted the direction of the price change 48.45% of the time.
# For a 18-day horizon, the model correctly predicted the direction of the price change 48.46% of the time.
# For a 19-day horizon, the model correctly predicted the direction of the price change 48.44% of the time.
# For a 20-day horizon, the model correctly predicted the direction of the price change 48.41% of the time.

# %%
df_a['Predicted_pct_change'] = abs(df_a['Predicted_change'] / df_a['Price'])*100
days = 5

# Calculate the percentage of times the prediction was correct
for threshold in [i for i in range(0, 1000, 5)]:
    # Only consider rows where we have enough data in the future
    df_i = df_a[df_a['Predicted_pct_change'] > threshold]
    percentage_correct = df_i[f'Same_direction_{days}'].mean() * 100
    print(f"With threshold {threshold}, the model correctly predicted the direction of the price change {percentage_correct:.2f}% of the time.")
# Out:
# With threshold 0, the model correctly predicted the direction of the price change 49.78% of the time.
# With threshold 5, the model correctly predicted the direction of the price change 51.59% of the time.
# With threshold 10, the model correctly predicted the direction of the price change 53.14% of the time.
# With threshold 15, the model correctly predicted the direction of the price change 54.15% of the time.
# With threshold 20, the model correctly predicted the direction of the price change 54.94% of the time.
# With threshold 25, the model correctly predicted the direction of the price change 55.58% of the time.
# With threshold 30, the model correctly predicted the direction of the price change 56.05% of the time.
# With threshold 35, the model correctly predicted the direction of the price change 56.48% of the time.
# With threshold 40, the model correctly predicted the direction of the price change 56.91% of the time.
# With threshold 45, the model correctly predicted the direction of the price change 57.35% of the time.
# With threshold 50, the model correctly predicted the direction of the price change 57.74% of the time.
# With threshold 55, the model correctly predicted the direction of the price change 58.15% of the time.
# With threshold 60, the model correctly predicted the direction of the price change 58.48% of the time.
# With threshold 65, the model correctly predicted the direction of the price change 58.83% of the time.
# With threshold 70, the model correctly predicted the direction of the price change 59.11% of the time.
# With threshold 75, the model correctly predicted the direction of the price change 59.36% of the time.
# With threshold 80, the model correctly predicted the direction of the price change 59.58% of the time.
# With threshold 85, the model correctly predicted the direction of the price change 59.79% of the time.
# With threshold 90, the model correctly predicted the direction of the price change 59.97% of the time.
# With threshold 95, the model correctly predicted the direction of the price change 60.15% of the time.
# With threshold 100, the model correctly predicted the direction of the price change 30.80% of the time.
# With threshold 105, the model correctly predicted the direction of the price change 30.44% of the time.
# With threshold 110, the model correctly predicted the direction of the price change 30.04% of the time.
# With threshold 115, the model correctly predicted the direction of the price change 29.78% of the time.
# With threshold 120, the model correctly predicted the direction of the price change 29.50% of the time.
# With threshold 125, the model correctly predicted the direction of the price change 29.25% of the time.
# With threshold 130, the model correctly predicted the direction of the price change 28.98% of the time.
# With threshold 135, the model correctly predicted the direction of the price change 28.76% of the time.
# With threshold 140, the model correctly predicted the direction of the price change 28.59% of the time.
# With threshold 145, the model correctly predicted the direction of the price change 28.25% of the time.
# With threshold 150, the model correctly predicted the direction of the price change 28.03% of the time.
# With threshold 155, the model correctly predicted the direction of the price change 27.84% of the time.
# With threshold 160, the model correctly predicted the direction of the price change 27.69% of the time.
# With threshold 165, the model correctly predicted the direction of the price change 27.50% of the time.
# With threshold 170, the model correctly predicted the direction of the price change 27.30% of the time.
# With threshold 175, the model correctly predicted the direction of the price change 27.13% of the time.
# With threshold 180, the model correctly predicted the direction of the price change 26.81% of the time.
# With threshold 185, the model correctly predicted the direction of the price change 26.84% of the time.
# With threshold 190, the model correctly predicted the direction of the price change 26.70% of the time.
# With threshold 195, the model correctly predicted the direction of the price change 26.65% of the time.
# With threshold 200, the model correctly predicted the direction of the price change 26.59% of the time.
# With threshold 205, the model correctly predicted the direction of the price change 26.41% of the time.
# With threshold 210, the model correctly predicted the direction of the price change 26.28% of the time.
# With threshold 215, the model correctly predicted the direction of the price change 26.30% of the time.
# With threshold 220, the model correctly predicted the direction of the price change 26.26% of the time.
# With threshold 225, the model correctly predicted the direction of the price change 26.44% of the time.
# With threshold 230, the model correctly predicted the direction of the price change 26.46% of the time.
# With threshold 235, the model correctly predicted the direction of the price change 26.59% of the time.
# With threshold 240, the model correctly predicted the direction of the price change 26.56% of the time.
# With threshold 245, the model correctly predicted the direction of the price change 26.74% of the time.
# With threshold 250, the model correctly predicted the direction of the price change 26.83% of the time.
# With threshold 255, the model correctly predicted the direction of the price change 27.11% of the time.
# With threshold 260, the model correctly predicted the direction of the price change 27.24% of the time.
# With threshold 265, the model correctly predicted the direction of the price change 27.43% of the time.
# With threshold 270, the model correctly predicted the direction of the price change 27.54% of the time.
# With threshold 275, the model correctly predicted the direction of the price change 27.65% of the time.
# With threshold 280, the model correctly predicted the direction of the price change 27.88% of the time.
# With threshold 285, the model correctly predicted the direction of the price change 27.84% of the time.
# With threshold 290, the model correctly predicted the direction of the price change 27.92% of the time.
# With threshold 295, the model correctly predicted the direction of the price change 28.06% of the time.
# With threshold 300, the model correctly predicted the direction of the price change 28.29% of the time.
# With threshold 305, the model correctly predicted the direction of the price change 28.34% of the time.
# With threshold 310, the model correctly predicted the direction of the price change 28.21% of the time.
# With threshold 315, the model correctly predicted the direction of the price change 28.26% of the time.
# With threshold 320, the model correctly predicted the direction of the price change 28.42% of the time.
# With threshold 325, the model correctly predicted the direction of the price change 28.49% of the time.
# With threshold 330, the model correctly predicted the direction of the price change 28.56% of the time.
# With threshold 335, the model correctly predicted the direction of the price change 28.84% of the time.
# With threshold 340, the model correctly predicted the direction of the price change 28.91% of the time.
# With threshold 345, the model correctly predicted the direction of the price change 29.22% of the time.
# With threshold 350, the model correctly predicted the direction of the price change 29.18% of the time.
# With threshold 355, the model correctly predicted the direction of the price change 29.13% of the time.
# With threshold 360, the model correctly predicted the direction of the price change 29.19% of the time.
# With threshold 365, the model correctly predicted the direction of the price change 29.28% of the time.
# With threshold 370, the model correctly predicted the direction of the price change 29.19% of the time.
# With threshold 375, the model correctly predicted the direction of the price change 29.10% of the time.
# With threshold 380, the model correctly predicted the direction of the price change 29.01% of the time.
# With threshold 385, the model correctly predicted the direction of the price change 29.18% of the time.
# With threshold 390, the model correctly predicted the direction of the price change 29.29% of the time.
# With threshold 395, the model correctly predicted the direction of the price change 29.25% of the time.
# With threshold 400, the model correctly predicted the direction of the price change 29.16% of the time.
# With threshold 405, the model correctly predicted the direction of the price change 29.14% of the time.
# With threshold 410, the model correctly predicted the direction of the price change 29.18% of the time.
# With threshold 415, the model correctly predicted the direction of the price change 29.06% of the time.
# With threshold 420, the model correctly predicted the direction of the price change 29.05% of the time.
# With threshold 425, the model correctly predicted the direction of the price change 29.13% of the time.
# With threshold 430, the model correctly predicted the direction of the price change 29.15% of the time.
# With threshold 435, the model correctly predicted the direction of the price change 29.16% of the time.
# With threshold 440, the model correctly predicted the direction of the price change 29.16% of the time.
# With threshold 445, the model correctly predicted the direction of the price change 29.10% of the time.
# With threshold 450, the model correctly predicted the direction of the price change 29.21% of the time.
# With threshold 455, the model correctly predicted the direction of the price change 29.21% of the time.
# With threshold 460, the model correctly predicted the direction of the price change 29.26% of the time.
# With threshold 465, the model correctly predicted the direction of the price change 29.31% of the time.
# With threshold 470, the model correctly predicted the direction of the price change 29.27% of the time.
# With threshold 475, the model correctly predicted the direction of the price change 29.53% of the time.
# With threshold 480, the model correctly predicted the direction of the price change 29.41% of the time.
# With threshold 485, the model correctly predicted the direction of the price change 29.55% of the time.
# With threshold 490, the model correctly predicted the direction of the price change 29.43% of the time.
# With threshold 495, the model correctly predicted the direction of the price change 29.36% of the time.
# With threshold 500, the model correctly predicted the direction of the price change 29.32% of the time.
# With threshold 505, the model correctly predicted the direction of the price change 29.37% of the time.
# With threshold 510, the model correctly predicted the direction of the price change 29.44% of the time.
# With threshold 515, the model correctly predicted the direction of the price change 29.44% of the time.
# With threshold 520, the model correctly predicted the direction of the price change 29.49% of the time.
# With threshold 525, the model correctly predicted the direction of the price change 29.50% of the time.
# With threshold 530, the model correctly predicted the direction of the price change 29.44% of the time.
# With threshold 535, the model correctly predicted the direction of the price change 29.42% of the time.
# With threshold 540, the model correctly predicted the direction of the price change 29.32% of the time.
# With threshold 545, the model correctly predicted the direction of the price change 29.27% of the time.
# With threshold 550, the model correctly predicted the direction of the price change 29.30% of the time.
# With threshold 555, the model correctly predicted the direction of the price change 29.37% of the time.
# With threshold 560, the model correctly predicted the direction of the price change 29.39% of the time.
# With threshold 565, the model correctly predicted the direction of the price change 29.23% of the time.
# With threshold 570, the model correctly predicted the direction of the price change 29.19% of the time.
# With threshold 575, the model correctly predicted the direction of the price change 29.19% of the time.
# With threshold 580, the model correctly predicted the direction of the price change 29.11% of the time.
# With threshold 585, the model correctly predicted the direction of the price change 29.08% of the time.
# With threshold 590, the model correctly predicted the direction of the price change 29.09% of the time.
# With threshold 595, the model correctly predicted the direction of the price change 29.29% of the time.
# With threshold 600, the model correctly predicted the direction of the price change 29.42% of the time.
# With threshold 605, the model correctly predicted the direction of the price change 29.36% of the time.
# With threshold 610, the model correctly predicted the direction of the price change 29.34% of the time.
# With threshold 615, the model correctly predicted the direction of the price change 29.33% of the time.
# With threshold 620, the model correctly predicted the direction of the price change 29.33% of the time.
# With threshold 625, the model correctly predicted the direction of the price change 29.43% of the time.
# With threshold 630, the model correctly predicted the direction of the price change 29.59% of the time.
# With threshold 635, the model correctly predicted the direction of the price change 29.65% of the time.
# With threshold 640, the model correctly predicted the direction of the price change 29.60% of the time.
# With threshold 645, the model correctly predicted the direction of the price change 29.73% of the time.
# With threshold 650, the model correctly predicted the direction of the price change 29.85% of the time.
# With threshold 655, the model correctly predicted the direction of the price change 29.80% of the time.
# With threshold 660, the model correctly predicted the direction of the price change 29.87% of the time.
# With threshold 665, the model correctly predicted the direction of the price change 29.77% of the time.
# With threshold 670, the model correctly predicted the direction of the price change 29.68% of the time.
# With threshold 675, the model correctly predicted the direction of the price change 29.77% of the time.
# With threshold 680, the model correctly predicted the direction of the price change 29.76% of the time.
# With threshold 685, the model correctly predicted the direction of the price change 29.84% of the time.
# With threshold 690, the model correctly predicted the direction of the price change 29.81% of the time.
# With threshold 695, the model correctly predicted the direction of the price change 29.84% of the time.
# With threshold 700, the model correctly predicted the direction of the price change 29.67% of the time.
# With threshold 705, the model correctly predicted the direction of the price change 29.76% of the time.
# With threshold 710, the model correctly predicted the direction of the price change 29.72% of the time.
# With threshold 715, the model correctly predicted the direction of the price change 29.68% of the time.
# With threshold 720, the model correctly predicted the direction of the price change 29.72% of the time.
# With threshold 725, the model correctly predicted the direction of the price change 29.53% of the time.
# With threshold 730, the model correctly predicted the direction of the price change 29.22% of the time.
# With threshold 735, the model correctly predicted the direction of the price change 29.18% of the time.
# With threshold 740, the model correctly predicted the direction of the price change 29.13% of the time.
# With threshold 745, the model correctly predicted the direction of the price change 28.95% of the time.
# With threshold 750, the model correctly predicted the direction of the price change 28.79% of the time.
# With threshold 755, the model correctly predicted the direction of the price change 28.54% of the time.
# With threshold 760, the model correctly predicted the direction of the price change 28.47% of the time.
# With threshold 765, the model correctly predicted the direction of the price change 28.40% of the time.
# With threshold 770, the model correctly predicted the direction of the price change 28.40% of the time.
# With threshold 775, the model correctly predicted the direction of the price change 28.43% of the time.
# With threshold 780, the model correctly predicted the direction of the price change 28.38% of the time.
# With threshold 785, the model correctly predicted the direction of the price change 28.34% of the time.
# With threshold 790, the model correctly predicted the direction of the price change 28.19% of the time.
# With threshold 795, the model correctly predicted the direction of the price change 28.28% of the time.
# With threshold 800, the model correctly predicted the direction of the price change 28.12% of the time.
# With threshold 805, the model correctly predicted the direction of the price change 27.95% of the time.
# With threshold 810, the model correctly predicted the direction of the price change 27.92% of the time.
# With threshold 815, the model correctly predicted the direction of the price change 27.71% of the time.
# With threshold 820, the model correctly predicted the direction of the price change 27.65% of the time.
# With threshold 825, the model correctly predicted the direction of the price change 27.43% of the time.
# With threshold 830, the model correctly predicted the direction of the price change 27.20% of the time.
# With threshold 835, the model correctly predicted the direction of the price change 27.18% of the time.
# With threshold 840, the model correctly predicted the direction of the price change 27.22% of the time.
# With threshold 845, the model correctly predicted the direction of the price change 27.10% of the time.
# With threshold 850, the model correctly predicted the direction of the price change 27.04% of the time.
# With threshold 855, the model correctly predicted the direction of the price change 27.11% of the time.
# With threshold 860, the model correctly predicted the direction of the price change 27.28% of the time.
# With threshold 865, the model correctly predicted the direction of the price change 27.13% of the time.
# With threshold 870, the model correctly predicted the direction of the price change 27.25% of the time.
# With threshold 875, the model correctly predicted the direction of the price change 27.25% of the time.
# With threshold 880, the model correctly predicted the direction of the price change 27.19% of the time.
# With threshold 885, the model correctly predicted the direction of the price change 27.17% of the time.
# With threshold 890, the model correctly predicted the direction of the price change 27.33% of the time.
# With threshold 895, the model correctly predicted the direction of the price change 27.51% of the time.
# With threshold 900, the model correctly predicted the direction of the price change 27.33% of the time.
# With threshold 905, the model correctly predicted the direction of the price change 27.20% of the time.
# With threshold 910, the model correctly predicted the direction of the price change 27.33% of the time.
# With threshold 915, the model correctly predicted the direction of the price change 27.30% of the time.
# With threshold 920, the model correctly predicted the direction of the price change 27.41% of the time.
# With threshold 925, the model correctly predicted the direction of the price change 27.25% of the time.
# With threshold 930, the model correctly predicted the direction of the price change 27.29% of the time.
# With threshold 935, the model correctly predicted the direction of the price change 27.15% of the time.
# With threshold 940, the model correctly predicted the direction of the price change 27.15% of the time.
# With threshold 945, the model correctly predicted the direction of the price change 27.19% of the time.
# With threshold 950, the model correctly predicted the direction of the price change 27.10% of the time.
# With threshold 955, the model correctly predicted the direction of the price change 26.98% of the time.
# With threshold 960, the model correctly predicted the direction of the price change 26.93% of the time.
# With threshold 965, the model correctly predicted the direction of the price change 26.78% of the time.
# With threshold 970, the model correctly predicted the direction of the price change 26.52% of the time.
# With threshold 975, the model correctly predicted the direction of the price change 26.47% of the time.
# With threshold 980, the model correctly predicted the direction of the price change 26.46% of the time.
# With threshold 985, the model correctly predicted the direction of the price change 26.49% of the time.
# With threshold 990, the model correctly predicted the direction of the price change 26.40% of the time.
# With threshold 995, the model correctly predicted the direction of the price change 26.43% of the time.

# %%
import pandas as pd

# Assuming df is your DataFrame
df_a = df.sort_values(by=['Strike', 'Expiry_date', 'Quote_date'])

# Calculate the actual change in market price
df_a['Actual_change'] = df_a.groupby(['Strike', 'Expiry_date'])['Price'].diff()

print(df_a.head(20))

# Calculate whether the predicted change in market price is in the same direction as the actual change
df_a['Same_direction'] = np.sign(df_a['Prediction'].diff()) == np.sign(df_a['Actual_change'])

# Calculate the percentage of times the prediction was correct for each year
df_a['Quote_date'] = pd.to_datetime(df_a['Quote_date'])
df_a['Year'] = df_a['Quote_date'].dt.year

print(df_a.head(20))

for year in range(2015, 2024):
    df_year = df_a[df_a['Year'] == year]
    percentage_correct = df_year['Same_direction'].mean() * 100
    print(f"In {year}, the model correctly predicted the direction of the price change {percentage_correct:.2f}% of the time.")
# Out:
#         Unnamed: 0 Quote_date    Price  Prediction  Underlying_last  Strike  \
# 954145     2472301 2016-02-11  903.650   909.63666          1828.57   925.0
# 955064     2473220 2016-02-11  899.755   906.24960          1828.57   925.0
# 956769     2474925 2016-02-11  891.245   897.38837          1828.57   925.0
# 956937     2475093 2016-02-11  884.895   888.44543          1828.57   925.0
# 957040     2475196 2016-02-11  879.355   881.87634          1828.57   925.0
# 957147     2475303 2016-02-11  877.350   878.72327          1828.57   925.0
# 957202     2475358 2016-02-11  870.855   867.65344          1828.57   925.0
# 957257     2475413 2016-02-11  862.195   861.09094          1828.57   925.0
# 542232     2060388 2015-08-24  943.360   938.52110          1893.63   950.0
# 545883     2064039 2015-08-25  916.850   912.99530          1868.19   950.0
# 542405     2060561 2015-08-24  943.200   938.32370          1893.63   950.0
# 546067     2064223 2015-08-25  916.600   912.81445          1868.19   950.0
# 542580     2060736 2015-08-24  942.405   938.03810          1893.63   950.0
# 546252     2064408 2015-08-25  916.400   912.64105          1868.19   950.0
# 542756     2060912 2015-08-24  939.255   937.58230          1893.63   950.0
# 546444     2064600 2015-08-25  915.405   912.36820          1868.19   950.0
# 542932     2061088 2015-08-24  941.005   937.30000          1893.63   950.0
# 546636     2064792 2015-08-25  913.850   912.11110          1868.19   950.0
# 543153     2061309 2015-08-24  940.240   936.79785          1893.63   950.0
# 546856     2065012 2015-08-25  914.800   911.60340          1868.19   950.0
#
#              TTM         R Expiry_date  Actual_change  Same_direction  Year
# 954145  0.019178  0.002700  2016-02-18            NaN           False  2016
# 955064  0.095890  0.002636  2016-03-17            NaN           False  2016
# 956769  0.345205  0.003300  2016-06-16            NaN           False  2016
# 956937  0.597260  0.003912  2016-09-16            NaN           False  2016
# 957040  0.846575  0.004461  2016-12-16            NaN           False  2016
# 957147  0.942466  0.004658  2017-01-20            NaN           False  2016
# 957202  1.345205  0.005407  2017-06-16            NaN           False  2016
# 957257  1.843836  0.006179  2017-12-15            NaN           False  2016
# 542232  0.010959  0.000200  2015-08-28            NaN           False  2015
# 545883  0.008219  0.000400  2015-08-28        -26.510            True  2015
# 542405  0.019178  0.000200  2015-08-31            NaN           False  2015
# 546067  0.016438  0.000400  2015-08-31        -26.600            True  2015
# 542580  0.030137  0.000200  2015-09-04            NaN           False  2015
# 546252  0.027397  0.000400  2015-09-04        -26.005            True  2015
# 542756  0.049315  0.000200  2015-09-11            NaN           False  2015
# 546444  0.046575  0.000400  2015-09-11        -23.850            True  2015
# 542932  0.065753  0.000200  2015-09-17            NaN           False  2015
# 546636  0.063014  0.000400  2015-09-17        -27.155            True  2015
# 543153  0.087671  0.000152  2015-09-25            NaN           False  2015
# 546856  0.084932  0.000345  2015-09-25        -25.440            True  2015
#         Unnamed: 0 Quote_date    Price  Prediction  Underlying_last  Strike  \
# 954145     2472301 2016-02-11  903.650   909.63666          1828.57   925.0
# 955064     2473220 2016-02-11  899.755   906.24960          1828.57   925.0
# 956769     2474925 2016-02-11  891.245   897.38837          1828.57   925.0
# 956937     2475093 2016-02-11  884.895   888.44543          1828.57   925.0
# 957040     2475196 2016-02-11  879.355   881.87634          1828.57   925.0
# 957147     2475303 2016-02-11  877.350   878.72327          1828.57   925.0
# 957202     2475358 2016-02-11  870.855   867.65344          1828.57   925.0
# 957257     2475413 2016-02-11  862.195   861.09094          1828.57   925.0
# 542232     2060388 2015-08-24  943.360   938.52110          1893.63   950.0
# 545883     2064039 2015-08-25  916.850   912.99530          1868.19   950.0
# 542405     2060561 2015-08-24  943.200   938.32370          1893.63   950.0
# 546067     2064223 2015-08-25  916.600   912.81445          1868.19   950.0
# 542580     2060736 2015-08-24  942.405   938.03810          1893.63   950.0
# 546252     2064408 2015-08-25  916.400   912.64105          1868.19   950.0
# 542756     2060912 2015-08-24  939.255   937.58230          1893.63   950.0
# 546444     2064600 2015-08-25  915.405   912.36820          1868.19   950.0
# 542932     2061088 2015-08-24  941.005   937.30000          1893.63   950.0
# 546636     2064792 2015-08-25  913.850   912.11110          1868.19   950.0
# 543153     2061309 2015-08-24  940.240   936.79785          1893.63   950.0
# 546856     2065012 2015-08-25  914.800   911.60340          1868.19   950.0
#
#              TTM         R Expiry_date  Actual_change  Same_direction  Year
# 954145  0.019178  0.002700  2016-02-18            NaN           False  2016
# 955064  0.095890  0.002636  2016-03-17            NaN           False  2016
# 956769  0.345205  0.003300  2016-06-16            NaN           False  2016
# 956937  0.597260  0.003912  2016-09-16            NaN           False  2016
# 957040  0.846575  0.004461  2016-12-16            NaN           False  2016
# 957147  0.942466  0.004658  2017-01-20            NaN           False  2016
# 957202  1.345205  0.005407  2017-06-16            NaN           False  2016
# 957257  1.843836  0.006179  2017-12-15            NaN           False  2016
# 542232  0.010959  0.000200  2015-08-28            NaN           False  2015
# 545883  0.008219  0.000400  2015-08-28        -26.510            True  2015
# 542405  0.019178  0.000200  2015-08-31            NaN           False  2015
# 546067  0.016438  0.000400  2015-08-31        -26.600            True  2015
# 542580  0.030137  0.000200  2015-09-04            NaN           False  2015
# 546252  0.027397  0.000400  2015-09-04        -26.005            True  2015
# 542756  0.049315  0.000200  2015-09-11            NaN           False  2015
# 546444  0.046575  0.000400  2015-09-11        -23.850            True  2015
# 542932  0.065753  0.000200  2015-09-17            NaN           False  2015
# 546636  0.063014  0.000400  2015-09-17        -27.155            True  2015
# 543153  0.087671  0.000152  2015-09-25            NaN           False  2015
# 546856  0.084932  0.000345  2015-09-25        -25.440            True  2015
# In 2015, the model correctly predicted the direction of the price change 84.11% of the time.
# In 2016, the model correctly predicted the direction of the price change 80.41% of the time.
# In 2017, the model correctly predicted the direction of the price change 77.29% of the time.
# In 2018, the model correctly predicted the direction of the price change 78.30% of the time.
# In 2019, the model correctly predicted the direction of the price change 80.80% of the time.
# In 2020, the model correctly predicted the direction of the price change 84.91% of the time.
# In 2021, the model correctly predicted the direction of the price change 85.11% of the time.
# In 2022, the model correctly predicted the direction of the price change 82.22% of the time.
# In 2023, the model correctly predicted the direction of the price change 87.25% of the time.

# %%
# Assuming df is your DataFrame
df_a = df.sort_values(by=['Strike', 'Expiry_date', 'Quote_date'])

# Calculate the actual change in market price
df_a['Actual_change'] = df_a.groupby(['Strike', 'Expiry_date'])['Price'].diff()

# Calculate whether the predicted change in market price is in the same direction as the actual change
df_a['Same_direction'] = np.sign(df_a['Prediction'].diff()) == np.sign(df_a['Actual_change'])

# Split the predictions into positive and negative
df_a['Positive_prediction'] = (df_a['Prediction'].diff() > 0) & (df_a['Actual_change'] > 0)
df_a['Negative_prediction'] = (df_a['Prediction'].diff() < 0) & (df_a['Actual_change'] < 0)

# Calculate the percentage of times the prediction was correct for each year
df_a['Quote_date'] = pd.to_datetime(df_a['Quote_date'])
df_a['Year'] = df_a['Quote_date'].dt.year

for year in range(2015, 2024):
    df_year = df_a[df_a['Year'] == year]
    
    # Overall percentage
    percentage_correct = df_year['Same_direction'].mean() * 100
    print(f"In {year}, the model correctly predicted the direction of the price change {percentage_correct:.2f}% of the time.")
    
    # Positive percentage
    percentage_positive = df_year['Positive_prediction'].mean() * 100
    print(f"In {year}, the model correctly predicted the direction of the price increase {percentage_positive:.2f}% of the time.")
    
    # Negative percentage
    percentage_negative = df_year['Negative_prediction'].mean() * 100
    print(f"In {year}, the model correctly predicted the direction of the price decrease {percentage_negative:.2f}% of the time.")

# Overall percentage
percentage_correct = df_a['Same_direction'].mean() * 100
print(f"In total, the model correctly predicted the direction of the price change {percentage_correct:.2f}% of the time.")
    
# Positive percentage
percentage_positive = df_a['Positive_prediction'].mean() * 100
print(f"In total, the model correctly predicted the direction of the price increase {percentage_positive:.2f}% of the time.")
    
# Negative percentage
percentage_negative = df_a['Negative_prediction'].mean() * 100
print(f"In total, the model correctly predicted the direction of the price decrease {percentage_negative:.2f}% of the time.")
# Out:
# In 2015, the model correctly predicted the direction of the price change 84.11% of the time.
# In 2015, the model correctly predicted the direction of the price increase 38.51% of the time.
# In 2015, the model correctly predicted the direction of the price decrease 44.30% of the time.
# In 2016, the model correctly predicted the direction of the price change 80.41% of the time.
# In 2016, the model correctly predicted the direction of the price increase 40.28% of the time.
# In 2016, the model correctly predicted the direction of the price decrease 38.49% of the time.
# In 2017, the model correctly predicted the direction of the price change 77.29% of the time.
# In 2017, the model correctly predicted the direction of the price increase 41.82% of the time.
# In 2017, the model correctly predicted the direction of the price decrease 33.65% of the time.
# In 2018, the model correctly predicted the direction of the price change 78.30% of the time.
# In 2018, the model correctly predicted the direction of the price increase 38.31% of the time.
# In 2018, the model correctly predicted the direction of the price decrease 38.56% of the time.
# In 2019, the model correctly predicted the direction of the price change 80.80% of the time.
# In 2019, the model correctly predicted the direction of the price increase 45.35% of the time.
# In 2019, the model correctly predicted the direction of the price decrease 33.73% of the time.
# In 2020, the model correctly predicted the direction of the price change 84.91% of the time.
# In 2020, the model correctly predicted the direction of the price increase 46.58% of the time.
# In 2020, the model correctly predicted the direction of the price decrease 37.64% of the time.
# In 2021, the model correctly predicted the direction of the price change 85.11% of the time.
# In 2021, the model correctly predicted the direction of the price increase 47.02% of the time.
# In 2021, the model correctly predicted the direction of the price decrease 36.56% of the time.
# In 2022, the model correctly predicted the direction of the price change 82.22% of the time.
# In 2022, the model correctly predicted the direction of the price increase 32.40% of the time.
# In 2022, the model correctly predicted the direction of the price decrease 47.76% of the time.
# In 2023, the model correctly predicted the direction of the price change 87.25% of the time.
# In 2023, the model correctly predicted the direction of the price increase 44.05% of the time.
# In 2023, the model correctly predicted the direction of the price decrease 41.51% of the time.
# In total, the model correctly predicted the direction of the price change 82.21% of the time.
# In total, the model correctly predicted the direction of the price increase 41.50% of the time.
# In total, the model correctly predicted the direction of the price decrease 39.17% of the time.

# %%
# Add this after the 'Positive_prediction' and 'Negative_prediction' columns are created
df_a['No_change_prediction'] = (df_a['Prediction'].diff() == 0) & (df_a['Actual_change'] == 0)

# Add this inside the for loop, after the 'Negative_prediction' percentage is calculated
percentage_no_change = df_a['No_change_prediction'].mean() * 100
print(f"In total, the model correctly predicted no change in price {percentage_no_change:.2f}% of the time.")
# Out:
# In total, the model correctly predicted no change in price 1.54% of the time.

# %%
# Assuming df is your DataFrame
df_a = df.sort_values(by=['Strike', 'Expiry_date', 'Quote_date'])

# Calculate the actual change in market price
df_a['Actual_change'] = df_a.groupby(['Strike', 'Expiry_date'])['Price'].diff()

# Calculate whether the predicted change in market price is in the same direction as the actual change
df_a['Same_direction'] = np.sign(df_a['Prediction'].diff()) == np.sign(df_a['Actual_change'])

percentage_correct = df_a['Same_direction'].mean() * 100
print(f"The model correctly predicted the direction of the price change {percentage_correct:.2f}% of the time.")
# Out:
# The model correctly predicted the direction of the price change 82.21% of the time.

# %%
import pandas as pd
import numpy as np

# Assuming df_a is your DataFrame
df_b = df.sort_values(by=['Strike', 'Expiry_date', 'Quote_date'])

# Calculate the actual percentage change in market price for different days ahead
days_ahead = [1, 5, 10, 20]
for days in days_ahead:
    df_b[f'Actual_pct_change_{days}'] = df_b.groupby(['Strike', 'Expiry_date'])['Price'].pct_change(-days)

# Calculate the predicted percentage change in market price
df_b['Predicted_pct_change'] = (df_b['Prediction'] - df_b['Price']) / df_b['Price']

# Calculate the difference between the actual and predicted percentage changes
for days in days_ahead:
    df_b[f'Prediction_error_{days}'] = df_b[f'Predicted_pct_change'] - df_b[f'Actual_pct_change_{days}']

# Calculate the mean squared error of the predictions
for days in days_ahead:
    # Only consider rows where we have enough data in the future
    df_b = df_b.dropna(subset=[f'Actual_pct_change_{days}', f'Prediction_error_{days}'])
    mse = np.mean(df_b[f'Prediction_error_{days}']**2)
    print(f"For a {days}-day horizon, the mean squared error of the percentage change predictions is {mse:.5f}.")
# Out:
# For a 1-day horizon, the mean squared error of the percentage change predictions is 12.03828.
# For a 5-day horizon, the mean squared error of the percentage change predictions is 406.72524.
# For a 10-day horizon, the mean squared error of the percentage change predictions is 2913.63418.
# For a 20-day horizon, the mean squared error of the percentage change predictions is 14855.40632.

# %%
import pandas as pd
import numpy as np

# Assuming df_b is your DataFrame
df_b = df.sort_values(by=['Strike', 'Expiry_date', 'Quote_date'])

# Calculate the actual absolute change in market price for different days ahead
days_ahead = [1, 5, 10, 20]
for days in days_ahead:
    df_b[f'Actual_change_{days}'] = df_b.groupby(['Strike', 'Expiry_date'])['Price'].shift(-days) - df_b['Price']

# Calculate the predicted absolute change in market price
df_b['Predicted_change'] = df_b['Prediction'] - df_b['Price']

# Calculate the difference between the actual and predicted absolute changes
for days in days_ahead:
    df_b[f'Prediction_error_{days}'] = df_b['Predicted_change'] - df_b[f'Actual_change_{days}']

# Calculate the root mean squared error of the predictions
for days in days_ahead:
    # Only consider rows where we have enough data in the future
    df_b = df_b.dropna(subset=[f'Actual_change_{days}', f'Prediction_error_{days}'])
    rmse = np.sqrt(np.mean(df_b[f'Prediction_error_{days}']**2))
    print(f"For a {days}-day horizon, the root mean squared error of the absolute change predictions is {rmse:.5f}.")
# Out:
# For a 1-day horizon, the root mean squared error of the absolute change predictions is 30.22283.
# For a 5-day horizon, the root mean squared error of the absolute change predictions is 59.04197.
# For a 10-day horizon, the root mean squared error of the absolute change predictions is 80.81865.
# For a 20-day horizon, the root mean squared error of the absolute change predictions is 113.63054.

# %%
# Assuming df_a is your DataFrame
df_a = df.copy()

model_names = ['LSTM-MLP', 'Heston', 'IV', 'GARCH', 'Rolling']

# Iterate over the models
for model_name in model_names:
    print(f"For model: {model_name}")

    # Rename the prediction column
    df_a = df_a.rename(columns={model_name: 'Prediction'})

    # Calculate the predicted change and relative pricing error
    df_a['Predicted_change'] = (df_a['Prediction'] - df_a['Price'])
    df_a['Relative_pricing_error'] = df_a['Predicted_change'] / df_a['Price']

    # Define a list of thresholds
    thresholds = [0.01]

    # Calculate the actual change in market price for different days ahead
    days_ahead = [5]
    for days in days_ahead:
        df_a[f'Actual_change_{days}'] = df_a.groupby(['Option_ID'])['Price'].shift(-days) - df_a['Price']

    # Iterate over the thresholds
    for threshold in thresholds:
        print(f"For threshold {threshold * 100:.2f}%:")

        # Filter instances based on the threshold
        filtered_df = df_a[abs(df_a['Relative_pricing_error']) > threshold]

        # Determine if the actual and predicted changes are in the same direction
        for days in days_ahead:
            filtered_df[f'Same_direction_{days}'] = filtered_df[f'Actual_change_{days}'] * filtered_df['Predicted_change'] > 0

        # Calculate the percentage of times the prediction was correct
        for days in days_ahead:
            # Only consider rows where we have enough data in the future
            filtered_df = filtered_df.dropna(subset=[f'Actual_change_{days}', f'Same_direction_{days}'])

            # Calculate the number of up, down, and still predictions
            correct_predictions = filtered_df[f'Same_direction_{days}'].sum()
            up_predictions = filtered_df[filtered_df[f'Actual_change_{days}'] > 0][f'Same_direction_{days}'].sum()
            down_predictions = filtered_df[filtered_df[f'Actual_change_{days}'] < 0][f'Same_direction_{days}'].sum()

            # Calculate the total up, down, and still predictions
            total_predictions = filtered_df[f'Same_direction_{days}'].count()
            total_up_predictions = filtered_df[filtered_df[f'Actual_change_{days}'] > 0][f'Same_direction_{days}'].count()
            total_down_predictions = filtered_df[filtered_df[f'Actual_change_{days}'] < 0][f'Same_direction_{days}'].count()

            # Calculate the percentages of correct up, down, and still predictions
            percentage_correct = correct_predictions / total_predictions * 100
            percentage_up = up_predictions / total_up_predictions * 100
            percentage_down = down_predictions / total_down_predictions * 100

            print(f"For a {days}-day horizon:")
            print(f"  Total percentage of correct predictions: {percentage_correct:.2f}%")
            print(f"  Percentage of correct UP predictions: {percentage_up:.2f}%")
            print(f"  Percentage of correct DOWN predictions: {percentage_down:.2f}%")
            print()
