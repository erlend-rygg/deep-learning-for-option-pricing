# %% [markdown]
# ### Imports

# %%
import pandas as pd
import datetime
import os
import sys
import math
import matplotlib.pyplot as plt
import numpy as np
import warnings
from pandas.errors import SettingWithCopyWarning
import dask.dataframe as dd


warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)

# %% [markdown]
# ### Parameters

# %%
google_colab = False

# %% [markdown]
# ### Data loading

# %%
# Set the path to the root directory
path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
# Read dataframes using Dask
df = dd.read_csv(path + '/data/predictions/combined_predictions_BS_v2.csv')
df_ba = dd.read_csv(path + '/data/processed_data/2011_11feb-2023mar_NSS_filtered_with_BID_ASK_IV_DELTA.csv')
df["Quote_date"] = dd.to_datetime(df["Quote_date"])
df_ba["Quote_date"] = dd.to_datetime(df_ba["Quote_date"])


df = df[df['Quote_date'] >= '2015-01-11']
df_ba = df_ba[df_ba['Quote_date'] >= '2015-01-11']

# In df, rename IV to BS-IV
df = df.rename(columns={"IV": "BS-IV"})
# In df_ba, drop

# %%
df = df_ba.merge(df, on=["Quote_date", "TTM", "Strike"], how="inner", suffixes=("", "_drop"))

# %% [markdown]
# ### Data processing

# %%
# Turning the dask dataframe into a pandas dataframe
df = df.compute()

# %%
# Drop the columns that were duplicated
df = df.drop(columns=["Unnamed: 0", "Underlying_last_drop", "R_drop"])

# %%
display(df)
# Out:
#        Quote_date Expire_date     Price     Bid      Ask  Underlying_last
# 0      2015-01-12  2015-01-15   603.295   602.2   604.39          2028.56  \
# 1      2015-01-12  2015-01-15   483.900   482.4   485.40          2028.56
# 2      2015-01-12  2015-01-15   468.450   467.2   469.70          2028.56
# 3      2015-01-12  2015-01-15   363.550   362.4   364.70          2028.56
# 4      2015-01-12  2015-01-15   322.950   321.9   324.00          2028.56
# ...           ...         ...       ...     ...      ...              ...
# 436709 2023-03-31  2024-04-19   422.450   420.0   424.90          4109.88
# 436710 2023-03-31  2024-04-19   360.050   357.7   362.40          4109.88
# 436711 2023-03-31  2024-06-21  1556.450  1544.9  1568.00          4109.88
# 436712 2023-03-31  2024-06-21   441.050   439.4   442.70          4109.88
# 436713 2023-03-31  2024-06-21   349.350   347.9   350.80          4109.88
#
#         Strike       TTM    Delta       IV         R  Price_drop      Rolling
# 0       1425.0  0.008219  1.00000  0.00000  0.000200     603.295   603.562342  \
# 1       1545.0  0.008219  0.99564  1.02531  0.000200     483.900   483.562540
# 2       1560.0  0.008219  1.00000  0.00000  0.000200     468.450   468.562564
# 3       1665.0  0.008219  1.00000  0.00000  0.000200     363.550   363.562737
# 4       1705.0  0.008219  1.00000  0.00000  0.000200     322.950   323.562803
# ...        ...       ...      ...      ...       ...         ...          ...
# 436709  4075.0  1.054795  0.61661  0.20127  0.046174     422.450   413.842527
# 436710  4175.0  1.054795  0.57119  0.19367  0.046174     360.050   360.096980
# 436711  2675.0  1.227397  0.92096  0.31054  0.045030    1556.450  1579.926061
# 436712  4100.0  1.227397  0.60836  0.20096  0.045030     441.050   436.190941
# 436713  4250.0  1.227397  0.54445  0.18940  0.045030     349.350   359.110683
#
#               GARCH        BS-IV       Heston    LSTM-MLP
# 0        603.562342   643.551645   605.290994   603.12946
# 1        483.562540   496.670262   485.306680   483.69577
# 2        468.562564   483.219698   467.614355   468.75870
# 3        363.562737   374.802509   361.991271   364.29678
# 4        323.562803   330.141073   323.068179   324.65866
# ...             ...          ...          ...         ...
# 436709   366.069425   460.903651   425.307917   472.97458
# 436710   309.693752   396.952162   366.215057   411.19080
# 436711  1578.874712  1616.257310  1555.101104  1584.21610
# 436712   384.288997   481.722637   443.870558   496.36075
# 436713   303.752071   390.276196   358.377463   407.54080
#
# [10514930 rows x 17 columns]

# %%
# Dates
df["TTM"] = (df["TTM"] * 365).astype(int)
df['Expiry_date'] = pd.to_datetime(df['Expire_date'])
df['Quote_date'] = pd.to_datetime(df['Quote_date'])

# Adding option ID
df["Option_ID"] = df["Expiry_date"].astype(str) + "-" + df["Strike"].astype(str)

# Period to be traded on
df = df[(df["Expiry_date"] >= "2015-01-01") & (df["Expiry_date"] <= "2023-03-31")]
df = df[(df["Quote_date"] >= "2015-01-01") & (df["Quote_date"] <= "2023-03-31")]

# %% [markdown]
# Create underlying dict

# %%
# Create dict with Quote_date as key and Underlying_last as key
underlying_last_dict = df.groupby("Quote_date")["Underlying_last"].mean().to_dict()

# %% [markdown]
# Adding TTM=0 row

# %%
# Start by grouping the DataFrame by 'Option_ID'
groups = df.groupby("Option_ID")

# List to keep track of Option_IDs to delete
options_to_delete = []

def add_row(group):
    # Taking the last row from option group to be used in getting the Strike price
    last_row = group.iloc[-1]
    expiry_date = last_row['Expiry_date']

    # The first time Quote_date is the first day of the month, print the Quote_date
    if last_row['Quote_date'].day == 1 and last_row['Quote_date'].month in [1, 4, 7, 10]:
        print(last_row['Quote_date'])

    # If underlying_last_dict[expiry_date] is not defined, mark the Option_ID for deletion
    if expiry_date not in underlying_last_dict:
        print("Marked option for deletion: " + str(last_row['Option_ID']) + " on date: " + str(last_row['Quote_date']) + " due to missing underlying price.")
        options_to_delete.append(last_row['Option_ID'])
        # Return an empty DataFrame
        return pd.DataFrame()

    # Get the underlying price on the day of expiry
    underlying_last_on_expiry = underlying_last_dict[expiry_date]

    # Calculate the intrinsic value
    intrinsic_value = np.maximum(underlying_last_on_expiry - last_row['Strike'], 0)

    new_row = last_row.copy()
    new_row['Quote_date'] = expiry_date
    new_row['Expiry_date'] = expiry_date
    new_row['TTM'] = 0
    new_row['Underlying_last'] = underlying_last_on_expiry
    new_row['Price'] = intrinsic_value

    # Return the group concatenated with the new row
    return pd.concat([group, pd.DataFrame(new_row).transpose()])

# Apply the function to each group
df = groups.apply(add_row)

# After the group operation, filter df to exclude the Option_IDs that need to be deleted
df = df[~df['Option_ID'].isin(options_to_delete)]

# Reset the index (since the groupby operation changes it)
df = df.reset_index(drop=True)

# Sort the dataframe by Quote_date and Expiry_date
df = df.sort_values(['Quote_date', 'Expiry_date'])
# Out:
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-04-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-07-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-07-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2015-10-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-04-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# 2016-07-01 00:00:00
# Marked option for deletion: 2017-09-27-1500.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1600.0 on date: 2017-09-01 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1650.0 on date: 2017-08-22 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1700.0 on date: 2017-09-13 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1750.0 on date: 2017-09-13 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1800.0 on date: 2017-09-07 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1850.0 on date: 2017-08-31 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1900.0 on date: 2017-09-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# 2018-10-01 00:00:00
# Marked option for deletion: 2019-03-01-1300.0 on date: 2019-01-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1350.0 on date: 2019-01-29 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1400.0 on date: 2019-02-27 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1450.0 on date: 2019-02-11 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1500.0 on date: 2019-01-11 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1550.0 on date: 2019-02-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1600.0 on date: 2019-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1650.0 on date: 2019-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1700.0 on date: 2019-02-12 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1750.0 on date: 2019-02-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1800.0 on date: 2019-02-06 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1850.0 on date: 2019-01-04 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1875.0 on date: 2019-02-12 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1900.0 on date: 2019-01-03 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1925.0 on date: 2019-02-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1950.0 on date: 2019-01-23 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1975.0 on date: 2019-01-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2000.0 on date: 2019-02-19 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2010.0 on date: 2019-01-31 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2020.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2025.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2030.0 on date: 2019-01-17 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2040.0 on date: 2019-01-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2050.0 on date: 2019-02-25 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2060.0 on date: 2019-02-05 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2070.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2075.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2080.0 on date: 2019-02-07 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2090.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2100.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2110.0 on date: 2019-02-14 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2120.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2125.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2130.0 on date: 2019-02-06 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2140.0 on date: 2019-01-10 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2150.0 on date: 2019-02-12 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2160.0 on date: 2019-02-12 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2170.0 on date: 2019-02-06 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2175.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2180.0 on date: 2019-02-11 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2190.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2200.0 on date: 2019-02-14 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2205.0 on date: 2019-02-05 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2210.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2215.0 on date: 2019-01-11 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2220.0 on date: 2019-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2225.0 on date: 2019-01-10 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2230.0 on date: 2019-01-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2235.0 on date: 2019-01-22 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2240.0 on date: 2019-02-06 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2245.0 on date: 2019-01-29 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2250.0 on date: 2019-01-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2255.0 on date: 2019-02-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2260.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2265.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2270.0 on date: 2019-02-19 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2275.0 on date: 2019-01-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2280.0 on date: 2019-01-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2285.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2290.0 on date: 2019-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2295.0 on date: 2019-01-29 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2300.0 on date: 2019-01-10 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2305.0 on date: 2019-02-14 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2310.0 on date: 2019-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2315.0 on date: 2019-01-10 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2320.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2325.0 on date: 2019-02-13 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2330.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2335.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2340.0 on date: 2019-02-06 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2345.0 on date: 2019-02-04 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2350.0 on date: 2019-02-14 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2355.0 on date: 2019-02-25 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2360.0 on date: 2019-01-11 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2365.0 on date: 2019-02-27 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2370.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2375.0 on date: 2019-02-12 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2380.0 on date: 2019-02-19 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2385.0 on date: 2019-01-29 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2390.0 on date: 2019-02-12 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2395.0 on date: 2019-01-24 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2400.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2405.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2410.0 on date: 2019-02-13 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2415.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2420.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2425.0 on date: 2019-01-07 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2430.0 on date: 2019-02-19 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2435.0 on date: 2019-01-31 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2440.0 on date: 2019-01-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2445.0 on date: 2019-02-01 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2450.0 on date: 2019-02-01 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2455.0 on date: 2019-02-06 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2460.0 on date: 2019-02-07 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2465.0 on date: 2019-02-06 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2470.0 on date: 2019-02-12 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2475.0 on date: 2019-02-12 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2480.0 on date: 2019-02-14 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2485.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2490.0 on date: 2019-02-25 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2495.0 on date: 2019-01-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2500.0 on date: 2019-01-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2505.0 on date: 2019-02-06 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2510.0 on date: 2019-02-19 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2515.0 on date: 2019-02-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2520.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2525.0 on date: 2019-02-25 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2530.0 on date: 2019-01-03 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2535.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2540.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2545.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2550.0 on date: 2019-02-06 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2555.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2560.0 on date: 2019-01-09 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2565.0 on date: 2019-02-14 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2570.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2575.0 on date: 2019-02-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2580.0 on date: 2019-02-14 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2585.0 on date: 2019-02-07 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2590.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2595.0 on date: 2019-01-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2600.0 on date: 2019-01-24 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2605.0 on date: 2019-01-18 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2610.0 on date: 2019-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2615.0 on date: 2019-02-05 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2620.0 on date: 2019-02-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2625.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2630.0 on date: 2019-01-29 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2635.0 on date: 2019-01-17 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2640.0 on date: 2019-01-22 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2645.0 on date: 2019-02-06 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2650.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2655.0 on date: 2019-02-22 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2660.0 on date: 2019-02-13 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2665.0 on date: 2019-02-19 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2670.0 on date: 2019-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2675.0 on date: 2019-02-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2680.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2685.0 on date: 2019-02-11 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2690.0 on date: 2019-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2695.0 on date: 2019-02-19 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2700.0 on date: 2019-01-24 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2705.0 on date: 2019-01-11 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2710.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2715.0 on date: 2019-01-24 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2720.0 on date: 2019-02-27 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2725.0 on date: 2019-01-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2730.0 on date: 2019-02-12 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2735.0 on date: 2019-02-13 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2740.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2745.0 on date: 2019-01-22 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2750.0 on date: 2019-02-22 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2755.0 on date: 2019-01-24 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2760.0 on date: 2019-02-06 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2765.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2770.0 on date: 2019-02-22 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2775.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2780.0 on date: 2019-02-27 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2785.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2790.0 on date: 2019-01-18 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2795.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2800.0 on date: 2019-02-11 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2805.0 on date: 2019-02-14 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2810.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2815.0 on date: 2019-02-04 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2820.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2825.0 on date: 2019-01-23 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2830.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2835.0 on date: 2019-02-25 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2840.0 on date: 2019-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2845.0 on date: 2019-02-04 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2850.0 on date: 2019-01-22 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2855.0 on date: 2019-02-25 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2860.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2865.0 on date: 2019-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2870.0 on date: 2019-02-11 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2875.0 on date: 2019-02-13 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2880.0 on date: 2019-02-27 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2885.0 on date: 2019-02-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2890.0 on date: 2019-02-27 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2895.0 on date: 2019-02-27 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2900.0 on date: 2019-02-25 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2905.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2910.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2915.0 on date: 2019-02-06 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2920.0 on date: 2019-02-13 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2925.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2930.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2935.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2940.0 on date: 2019-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2945.0 on date: 2019-02-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2950.0 on date: 2019-02-05 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2955.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2960.0 on date: 2019-02-25 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2965.0 on date: 2019-02-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2970.0 on date: 2019-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2975.0 on date: 2019-02-14 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2980.0 on date: 2019-02-25 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2985.0 on date: 2019-02-27 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2990.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2995.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3000.0 on date: 2019-02-12 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3005.0 on date: 2019-02-27 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3010.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3015.0 on date: 2019-02-27 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3020.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3025.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3030.0 on date: 2019-02-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3050.0 on date: 2019-02-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3075.0 on date: 2019-02-27 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3100.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-
08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5600.0 on date: 2022-04-07 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5700.0 on date: 2022-03-30 00:00:00 due to missing underlying price.

# %%
display(df)

# %%
unique_dates = df['Quote_date'].unique()

# Remove option groups if it has a date between it's first and last that is not in unique_dates
for option_id in df.groupby("Option_ID").groups:
    option_group = df[df["Option_ID"] == option_id]
    group_first_date = option_group['Quote_date'].iloc[0]
    group_last_date = option_group['Quote_date'].iloc[-1]

    if group_first_date not in unique_dates or group_last_date not in unique_dates:
        df = df.drop(option_group.index)
        print("Dropped option group: ", option_id, " because it's first or last date is not in unique_dates")

    # If every unique_dates between group_first_date and group_last_date is not in group, drop the group
    dates_between = unique_dates[(unique_dates >= group_first_date) & (unique_dates <= group_last_date)]
    if len(dates_between) != len(option_group['Quote_date'].unique()):
        df = df.drop(option_group.index)
        print("Dropped option group: ", option_id, " because it's missing dates between it's first and last date")


    if len(option_group) < 2:
        df = df.drop(option_group.index)
        print("Dropped option group: ", option_id, " because it has less than 2 rows")
# Out:
# /var/folders/wk/x86_p6511l95p594k6qnb98h0000gn/T/ipykernel_43360/3551934751.py:6: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for option_id, option_group in option_groups:
# Dropped option group:  2018-01-19-1350.0  because it's missing dates between it's first and last date
# Dropped option group:  2018-01-19-1375.0  because it's missing dates between it's first and last date
# Dropped option group:  2018-01-19-1400.0  because it's missing dates between it's first and last date
# Dropped option group:  2018-01-19-3500.0  because it's missing dates between it's first and last date
# Dropped option group:  2018-01-26-1400.0  because it's missing dates between it's first and last date

# %%
display(df)
# Out:
#        Unnamed: 0 Quote_date     Price  Prediction  Underlying_last  Strike  \
# 0         4119222 2018-01-02  1095.295  1102.66750          2695.87  1600.0
# 1         4119223 2018-01-02   995.295  1002.39465          2695.87  1700.0
# 2         4119224 2018-01-02   945.300   952.23970          2695.87  1750.0
# 3         4119225 2018-01-02   895.305   902.30440          2695.87  1800.0
# 4         4119226 2018-01-02   845.290   852.40234          2695.87  1850.0
# ...           ...        ...       ...         ...              ...     ...
# 19206     4190191 2018-01-29     0.000     0.00000          2853.21  3010.0
# 19207     4190192 2018-01-29     0.000     0.00000          2853.21  3020.0
# 19208     4190193 2018-01-29     0.000     0.00000          2853.21  3050.0
# 19209     4190194 2018-01-29     0.000     0.00000          2853.21  3100.0
# 19210     4190195 2018-01-29     0.000     0.00000          2853.21  3125.0
#
#            TTM       R Expiry_date          Option_ID
# 0      0.00274  0.0129  2018-01-03  2018-01-03-1600.0
# 1      0.00274  0.0129  2018-01-03  2018-01-03-1700.0
# 2      0.00274  0.0129  2018-01-03  2018-01-03-1750.0
# 3      0.00274  0.0129  2018-01-03  2018-01-03-1800.0
# 4      0.00274  0.0129  2018-01-03  2018-01-03-1850.0
# ...        ...     ...         ...                ...
# 19206  0.00000  0.0124  2018-01-29  2018-01-29-3010.0
# 19207  0.00000  0.0124  2018-01-29  2018-01-29-3020.0
# 19208  0.00000  0.0124  2018-01-29  2018-01-29-3050.0
# 19209  0.00000  0.0124  2018-01-29  2018-01-29-3100.0
# 19210  0.00000  0.0124  2018-01-29  2018-01-29-3125.0
#
# [19176 rows x 10 columns]

# %%
# Write to csv
df.to_csv(path + '/data/trading/Full trading data - All models.csv', index=False)
