# %% [markdown]
# ### Imports

# %%
import pandas as pd
import datetime
import os
import sys
import math
import matplotlib.pyplot as plt
import numpy as np
import warnings
from pandas.errors import SettingWithCopyWarning


warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)

# %% [markdown]
# ### Parameters

# %%
google_colab = False

# %% [markdown]
# ### Data loading

# %%
if google_colab:
    from google.colab import drive
    drive.mount('/content/drive')
    # !pip install -U -q PyDrive
    from pydrive.auth import GoogleAuth
    from pydrive.drive import GoogleDrive
    from google.colab import auth
    from oauth2client.client import GoogleCredentials
    # Authenticate and create the PyDrive client.
    auth.authenticate_user()
    gauth = GoogleAuth()
    gauth.credentials = GoogleCredentials.get_application_default()
    drive = GoogleDrive(gauth)
    id = "1-kLmDPAmiTHNw_cv3lr6wY9DfSt8RSHv"
    downloaded = drive.CreateFile({'id':id}) 
    downloaded.GetContentFile('05-07_11-26.csv')  
    df = pd.read_csv('05-07_11-26.csv')
else:
    # Set the path to the root directory
    path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
    # Read dataframes using Dask
    df = pd.read_csv(path + '/data/predictions/11.05 1 mnd test sett full model run.csv')

# %% [markdown]
# ### Data processing

# %%
# Dates
df["TTM"] = (df["TTM"] * 365).astype(int)
df['Expiry_date'] = pd.to_datetime(df['Quote_date']) + pd.to_timedelta(df['TTM'], unit='D')
df['Quote_date'] = pd.to_datetime(df['Quote_date'])
df['Expiry_date'] = pd.to_datetime(df['Expiry_date'])

# Adding option ID
df["Option_ID"] = df["Expiry_date"].astype(str) + "-" + df["Strike"].astype(str)

# Period to be traded on
df = df[(df["Expiry_date"] >= "2015-01-01") & (df["Expiry_date"] <= "2023-03-31")]
df = df[(df["Quote_date"] >= "2015-01-01") & (df["Quote_date"] <= "2023-03-31")]

# %% [markdown]
# Adding TTM=0 row

# %%
# Sort the dataframe by Quote_date and Expiry_date
df = df.sort_values(['Quote_date', 'Expiry_date'])

groups = df.groupby(['Expiry_date', 'Strike'])

for _, group in groups:

    # Sort group so that the last row is the one with the lowest TTM
    group = group.sort_values('TTM', ascending=False)

    # Taking row from option group (could be any) to be used in getting the Strike price
    last_row = group.iloc[-1]
    
    expiry_date = last_row['Expiry_date']
    # Check is df.loc[df['Quote_date'] == expiry_date, 'Underlying_last'] is empty
    if df.loc[df['Quote_date'] == expiry_date, 'Underlying_last'].empty:
        print("No underlying price on expiry date: ", expiry_date)
        print("Weekday: ", expiry_date.weekday())
        # Remove the option_id from the dataframe
        df = df[df.Option_ID != last_row['Option_ID']]
        print("Option ID removed: ", last_row['Option_ID'])
        continue

    # Get the underlying price on the day of expiry
    underlying_last_on_expiry = df.loc[df['Quote_date'] == expiry_date, 'Underlying_last'].iloc[0]
    # Calculate the intrinsic value
    intrinsic_value = np.maximum(underlying_last_on_expiry - last_row['Strike'], 0)

    new_row = last_row.copy()
    new_row['Quote_date'] = expiry_date
    new_row['Expiry_date'] = expiry_date
    new_row['TTM'] = 0
    new_row['Underlying_last'] = underlying_last_on_expiry
    new_row['Price'] = intrinsic_value

    df = df.append(new_row, ignore_index=True)

# Sort the dataframe by Quote_date and Expiry_date
df = df.sort_values(['Quote_date', 'Expiry_date'])
# Out:
# /var/folders/wk/x86_p6511l95p594k6qnb98h0000gn/T/ipykernel_43360/3878844866.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# No underlying price on expiry date:  2015-08-30 00:00:00
# Weekday:  6
# Option ID removed:  2015-08-30-950.0
# No underlying price on expiry date:  2015-08-30 00:00:00
# Weekday:  6
# Option ID removed:  2015-08-30-1000.0
# No underlying price on expiry date:  2015-08-30 00:00:00
# Weekday:  6
# Option ID removed:  2015-08-30-
0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1420.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1425.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1430.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1435.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1440.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1445.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1450.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1455.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1460.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1465.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1470.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1475.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1480.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1485.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1490.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1495.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1500.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1505.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1510.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1515.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1520.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1525.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1530.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1535.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1540.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1545.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1550.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1555.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1560.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1565.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1570.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1575.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1580.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1585.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1590.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1595.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1600.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1605.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1610.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1615.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1620.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1625.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1630.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1635.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1640.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1645.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1650.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1655.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1660.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1665.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1670.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1675.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1680.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1685.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1690.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1695.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1700.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1705.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1710.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1715.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1720.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1725.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1730.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1735.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1740.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1745.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1750.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1755.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1760.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1765.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1770.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1775.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1780.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1785.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1790.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1795.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1800.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1805.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1810.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1815.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1820.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1825.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1830.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1835.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1840.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1845.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1850.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1855.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1860.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1865.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1870.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1875.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1880.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1885.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1890.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1895.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1900.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1905.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1910.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1915.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1920.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1925.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1930.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1935.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1940.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1945.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1950.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1955.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1960.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1965.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1970.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1975.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1980.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1985.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1990.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-1995.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2000.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2005.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2010.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2015.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2020.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2025.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2030.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2035.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2040.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2045.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2050.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2055.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2060.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2065.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2070.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2075.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2080.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2085.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2090.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2095.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2100.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2105.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2110.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2115.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2120.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2125.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2130.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2135.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2140.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2145.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2150.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2155.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2160.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2165.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2170.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2175.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2180.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2185.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2190.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2195.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2200.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2205.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2210.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2215.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2220.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2225.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2230.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2240.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2250.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2260.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2270.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2275.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2280.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2290.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2300.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2350.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2400.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2450.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2500.0
# No underlying price on expiry date:  2015-11-29 00:00:00
# Weekday:  6
# Option ID removed:  2015-11-29-2550.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-950.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1000.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1050.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1100.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1150.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1200.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1250.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1260.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1275.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1280.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1300.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1320.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1325.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1340.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1350.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1360.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1375.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6
# Option ID removed:  2016-02-28-1380.0
# No underlying price on expiry date:  2016-02-28 00:00:00
# Weekday:  6

# %%
unique_dates = df['Quote_date'].unique()

option_groups = df.groupby(['Option_ID'])

# Remove option groups if it has a date between it's first and last that is not in unique_dates
for option_id, option_group in option_groups:
    group_first_date = option_group['Quote_date'].iloc[0]
    group_last_date = option_group['Quote_date'].iloc[-1]

    if group_first_date not in unique_dates or group_last_date not in unique_dates:
        df = df.drop(option_group.index)
        print("Dropped option group: ", option_id, " because it's first or last date is not in unique_dates")

    # If every unique_dates between group_first_date and group_last_date is not in group, drop the group
    dates_between = unique_dates[(unique_dates >= group_first_date) & (unique_dates <= group_last_date)]
    if len(dates_between) != len(option_group['Quote_date'].unique()):
        df = df.drop(option_group.index)
        print("Dropped option group: ", option_id, " because it's missing dates between it's first and last date")


    if len(option_group) < 2:
        df = df.drop(option_group.index)
        print("Dropped option group: ", option_id, " because it has less than 2 rows")
# Out:
# /var/folders/wk/x86_p6511l95p594k6qnb98h0000gn/T/ipykernel_43360/3551934751.py:6: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for option_id, option_group in option_groups:
# Dropped option group:  2018-01-19-1350.0  because it's missing dates between it's first and last date
# Dropped option group:  2018-01-19-1375.0  because it's missing dates between it's first and last date
# Dropped option group:  2018-01-19-1400.0  because it's missing dates between it's first and last date
# Dropped option group:  2018-01-19-3500.0  because it's missing dates between it's first and last date
# Dropped option group:  2018-01-26-1400.0  because it's missing dates between it's first and last date

# %%
display(df)
# Out:
#        Unnamed: 0 Quote_date     Price  Prediction  Underlying_last  Strike  \
# 0         4119222 2018-01-02  1095.295  1102.66750          2695.87  1600.0
# 1         4119223 2018-01-02   995.295  1002.39465          2695.87  1700.0
# 2         4119224 2018-01-02   945.300   952.23970          2695.87  1750.0
# 3         4119225 2018-01-02   895.305   902.30440          2695.87  1800.0
# 4         4119226 2018-01-02   845.290   852.40234          2695.87  1850.0
# ...           ...        ...       ...         ...              ...     ...
# 19206     4190191 2018-01-29     0.000     0.00000          2853.21  3010.0
# 19207     4190192 2018-01-29     0.000     0.00000          2853.21  3020.0
# 19208     4190193 2018-01-29     0.000     0.00000          2853.21  3050.0
# 19209     4190194 2018-01-29     0.000     0.00000          2853.21  3100.0
# 19210     4190195 2018-01-29     0.000     0.00000          2853.21  3125.0
#
#            TTM       R Expiry_date          Option_ID
# 0      0.00274  0.0129  2018-01-03  2018-01-03-1600.0
# 1      0.00274  0.0129  2018-01-03  2018-01-03-1700.0
# 2      0.00274  0.0129  2018-01-03  2018-01-03-1750.0
# 3      0.00274  0.0129  2018-01-03  2018-01-03-1800.0
# 4      0.00274  0.0129  2018-01-03  2018-01-03-1850.0
# ...        ...     ...         ...                ...
# 19206  0.00000  0.0124  2018-01-29  2018-01-29-3010.0
# 19207  0.00000  0.0124  2018-01-29  2018-01-29-3020.0
# 19208  0.00000  0.0124  2018-01-29  2018-01-29-3050.0
# 19209  0.00000  0.0124  2018-01-29  2018-01-29-3100.0
# 19210  0.00000  0.0124  2018-01-29  2018-01-29-3125.0
#
# [19176 rows x 10 columns]

# %%
# Write to csv
df.to_csv(path + '/data/trading/Full trading data - LSTM-MLP.csv', index=False)
