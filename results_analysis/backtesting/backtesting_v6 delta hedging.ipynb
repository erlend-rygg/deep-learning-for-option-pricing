# %% [markdown]
# ### Imports and data loading

# %%
import pandas as pd
import datetime
import os
import sys
import math
import matplotlib.pyplot as plt
import numpy as np
import warnings
from pandas.errors import SettingWithCopyWarning
from scipy.stats import norm

warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# %% [markdown]
# ## Data loading

# %%
google_colab = False
if google_colab:
    from google.colab import drive
    drive.mount('/content/drive')
    # !pip install -U -q PyDrive
    from pydrive.auth import GoogleAuth
    from pydrive.drive import GoogleDrive
    from google.colab import auth
    from oauth2client.client import GoogleCredentials
    # Authenticate and create the PyDrive client.
    auth.authenticate_user()
    gauth = GoogleAuth()
    gauth.credentials = GoogleCredentials.get_application_default()
    drive = GoogleDrive(gauth)
    id = "kLmDPAmiTHNw_cv3lr6wY9DfSt8RSHv"
    downloaded = drive.CreateFile({'id':id}) 
    downloaded.GetContentFile('05-07_11-26.csv')  
    df = pd.read_csv('05-07_11-26.csv')
else:
    # Set the path to the root directory
    path = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
    sys.path.append(path)

    # Load Model 3 prediction file
    df = pd.read_csv(path + '/data/predictions/05-07_11-26.csv')

# %% [markdown]
# ### Data processing

# %%
df['Expiry_date'] = pd.to_datetime(df['Quote_date']) + pd.to_timedelta(df['TTM'] * 365, unit='D')

# %%
# FIlter between 2017-12-26 and 2018-02-01
df = df[(df['Quote_date'] >= '2015-01-01') & (df['Quote_date'] <= '2015-12-31')]
df = df[(df['Expiry_date'] >= '2015-01-01') & (df['Expiry_date'] <= '2015-12-31')]
df = df.sample(50000)

# %% [markdown]
# Adding ID

# %%
df["Option_ID"] = df["Expiry_date"].astype(str) + df["Strike"].astype(str)

# %% [markdown]
# Adding TTM=0 row

# %%
# Sort the dataframe by Quote_date and Expiry_date
df = df.sort_values(['Quote_date', 'Expiry_date'])

# Adding intrinsic value as Price on expirty date
# Iterate over every option, which is identified by the combination of Quote_date, Expiry_date, Strike
groups = df.groupby(['Expiry_date', 'Strike'])
for _, group in groups:
    # Create a new row for the date of expiry
    new_row = group.iloc[-1].copy()
    new_row['Price'] = max(0, new_row['Underlying_last'] - new_row['Strike'])
    new_row['TTM'] = 0
    new_row['Quote_date'] = new_row['Expiry_date']
    df = pd.concat([df, new_row.to_frame().transpose()], ignore_index=True)


# Quote_date and Expiry_date to datetime
df['Quote_date'] = pd.to_datetime(df['Quote_date'])
df['Expiry_date'] = pd.to_datetime(df['Expiry_date'])

df_read = df.copy()

# %% [markdown]
# ### Parameters

# %%
buy_threshold = 4
sell_threshold = 4
starting_balance = 1000000
delta_threshold = 0.2

# %% [markdown]
# ### Functions

# %%
df = df_read.copy()

# %%
def black_scholes_delta(S, K, T, r, sigma):
    d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
    try:
        delta = norm.cdf(d1)
    except:
        delta = 0
    return delta

def generate_buy_sell_signals(df, buy_threshold, sell_threshold):
    buy_signal = (df['Prediction'] - df['Price']) >= buy_threshold
    sell_signal = (df['Price'] - df['Prediction']) >= sell_threshold
    return buy_signal, sell_signal

def get_average_delta(df):
    df_bought = df[df['Position_this_opt'] == 1]
    df_sold = df[df['Position_this_opt'] == -1]
    df_bought['Delta'] = black_scholes_delta(df_bought['Underlying_last'].astype(float), df_bought['Strike'].astype(float), df_bought['TTM'].astype(float), 0.01, 0.3)
    df_sold['Delta'] = black_scholes_delta(df_sold['Underlying_last'].astype(float), df_sold['Strike'].astype(float), df_sold['TTM'].astype(float), 0.01, 0.3)
    portfolio_delta_avg = (df_bought['Delta'].sum() - df_sold['Delta'].sum()) / (len(df_bought) + len(df_sold))
    return portfolio_delta_avg


def calculate_options_value(df):
    df['Options_value'] = 0
    # Iterate over every Quote_date
    for date in df['Quote_date'].unique():
        # For every Quote date, multiply each row's Position_this_opt with the Price and sum it up.
        options_value_sum = (df.loc[df['Quote_date'] == date, 'Position_this_opt'] * df.loc[df['Quote_date'] == date, 'Price']).sum()
        # The result should be added to every row with the same Quote_date in the Options_value
        df.loc[df['Quote_date'] == date, 'Options_value'] = options_value_sum
    df['Total_value'] = df['Balance'] + df['Options_value']
    return df

# %%
def trader(df, buy_signal, sell_signal, starting_balance):
    df["Option_ID"] = df["Expiry_date"].astype(str) + df["Strike"].astype(str)
    last_date = df['Quote_date'].max()
    df = df[pd.to_datetime(df['Expiry_date']) < pd.to_datetime(last_date)]
    df['Signal'] = 0
    df.loc[buy_signal, 'Signal'] = 1
    df.loc[sell_signal, 'Signal'] = -1
    df['Balance'] = starting_balance
    df["Position_this_opt"] = 0

    quote_date_grouped = df.groupby('Quote_date')
    average_delta_last = 0

    # Iterate over every quote date
    for quote_date, group in quote_date_grouped:
        group = group.sample(frac=1)
        portfolio_size = 0
        new_delta = 0
        new_positions = 0

        # Iterate over every option on that quote date
        for _, row in group.iterrows():
            option_position = df.loc[(df['Option_ID'] == row['Option_ID']) & (df['Quote_date'] <= row['Quote_date']), 'Position_this_opt'].iloc[-1]

            # Buy the option
            if row['Signal'] == 1 and option_position == 0 and row['Balance'] >= row['Price'] and row["Quote_date"] != row["Expiry_date"] and average_delta_last < 0.2:
                option_position = 1
                df.loc[(df['Quote_date'] >= row['Quote_date']) & (df['Option_ID'] == row['Option_ID']), 'Position_this_opt'] = option_position
                df.loc[df['Quote_date'] >= row['Quote_date'], 'Balance'] -= row['Price']
                delta = black_scholes_delta(row['Underlying_last'], row['Strike'], row['TTM'], 0.01, 0.2)
                new_positions += 1
                new_delta += delta / new_positions
                average_delta_last = (average_delta_last * portfolio_size + delta) / (portfolio_size + 1)



            # Sell the option
            if row['Signal'] == -1 and option_position == 0 and row["Quote_date"] != row["Expiry_date"] and average_delta_last > - 0.2:
                option_position = -1
                df.loc[(df['Quote_date'] >= row['Quote_date']) & (df['Option_ID'] == row['Option_ID']), 'Position_this_opt'] = option_position
                df.loc[df['Quote_date'] >= row['Quote_date'], 'Balance'] += row['Price']
                delta = black_scholes_delta(row['Underlying_last'], row['Strike'], row['TTM'], 0.01, 0.2)
                new_positions += 1
                new_delta -= delta / new_positions
                average_delta_last = (average_delta_last * portfolio_size + delta) / (portfolio_size + 1)

            # Option expires
            if row["Quote_date"] == row["Expiry_date"] and option_position != 0:
                option_position = 0
                df.loc[(df['Quote_date'] > row['Quote_date']) & (df['Option_ID'] == row['Option_ID']), 'Position_this_opt'] = option_position
                intrinsic_value = max(0, row['Underlying_last'] - row['Strike'])
                adjustment = intrinsic_value if option_position == 1 else -intrinsic_value
                df.loc[df['Quote_date'] > row['Quote_date'], 'Balance'] += adjustment

            # Update portfolio size
            portfolio_size += abs(option_position)


        
        # Get average delta for all options held on that day
        average_delta_last = get_average_delta(df[df['Quote_date'] == quote_date])

        # For every quote date
        print("Quote date: ", quote_date, "Average delta: ", average_delta_last, "New delta:", new_delta ,"Number of options in portfolio: ", portfolio_size)

    return df

# %% [markdown]
# ### Run code

# %%
import warnings

warnings.filterwarnings('ignore', category=RuntimeWarning)

# %%
df = df_read.copy()
buy_signal, sell_signal = generate_buy_sell_signals(df, buy_threshold, sell_threshold)
df = trader(df, buy_signal, sell_signal, starting_balance)
df = calculate_options_value(df)
# Out:
# Quote date:  2015-01-02 00:00:00 Average delta:  -0.5376191839715492 New delta: -0.4008362042656016 Number of options in portfolio:  10
# Quote date:  2015-01-05 00:00:00 Average delta:  -0.2740815891526387 New delta: 0.3116329607258288 Number of options in portfolio:  4
# Quote date:  2015-01-06 00:00:00 Average delta:  -0.3028757727505435 New delta: 0.5421999641965034 Number of options in portfolio:  6
# Quote date:  2015-01-07 00:00:00 Average delta:  -0.12833671486493983 New delta: 0.8330027231915222 Number of options in portfolio:  6
# Quote date:  2015-01-08 00:00:00 Average delta:  0.09459213940354057 New delta: -0.41477593075901886 Number of options in portfolio:  3
# Quote date:  2015-01-09 00:00:00 Average delta:  0.05087391727994328 New delta: -0.38291617489576013 Number of options in portfolio:  6
# Quote date:  2015-01-12 00:00:00 Average delta:  -0.24229373978320934 New delta: 0.2011348945225853 Number of options in portfolio:  6
# Quote date:  2015-01-13 00:00:00 Average delta:  -0.5227746560232908 New delta: 0 Number of options in portfolio:  4
# Quote date:  2015-01-14 00:00:00 Average delta:  -0.4658139828005497 New delta: -0.5604106177412675 Number of options in portfolio:  31
# Quote date:  2015-01-15 00:00:00 Average delta:  -0.041101679252486534 New delta: 0 Number of options in portfolio:  5
# Quote date:  2015-01-16 00:00:00 Average delta:  -0.5232400349431149 New delta: -2.146312673057253 Number of options in portfolio:  48
# Quote date:  2015-01-20 00:00:00 Average delta:  -0.7829570815996836 New delta: 0 Number of options in portfolio:  2
# Quote date:  2015-01-21 00:00:00 Average delta:  -0.5298786775778714 New delta: 0 Number of options in portfolio:  9
# Quote date:  2015-01-22 00:00:00 Average delta:  -0.3599277780702827 New delta: 0.5298933251756472 Number of options in portfolio:  6
# Quote date:  2015-01-23 00:00:00 Average delta:  -0.206401912379649 New delta: 0.8433332851090098 Number of options in portfolio:  7
# Quote date:  2015-01-26 00:00:00 Average delta:  -0.13016035014434907 New delta: 0.6575120640120006 Number of options in portfolio:  9
# Quote date:  2015-01-27 00:00:00 Average delta:  -0.2576772506365385 New delta: 0.8239105291948234 Number of options in portfolio:  6
# Quote date:  2015-01-28 00:00:00 Average delta:  -0.15285564047087077 New delta: 0.6571005314610834 Number of options in portfolio:  11
# Quote date:  2015-01-29 00:00:00 Average delta:  -0.18095933523967167 New delta: 0.8702781542464465 Number of options in portfolio:  7
# Quote date:  2015-01-30 00:00:00 Average delta:  -0.448406750610198 New delta: -0.6335218918843332 Number of options in portfolio:  27
# Quote date:  2015-02-02 00:00:00 Average delta:  -0.2510808842748723 New delta: 0.6526900357713715 Number of options in portfolio:  6
# Quote date:  2015-02-03 00:00:00 Average delta:  -0.4196997004396944 New delta: 0.9814429301650172 Number of options in portfolio:  5
# Quote date:  2015-02-04 00:00:00 Average delta:  0.004831196058040277 New delta: 0.5532427241879347 Number of options in portfolio:  8
# Quote date:  2015-02-05 00:00:00 Average delta:  -0.33471924090113536 New delta: -0.055070666775991414 Number of options in portfolio:  18
# Quote date:  2015-02-06 00:00:00 Average delta:  -0.33089124787618285 New delta: -0.8308005645545619 Number of options in portfolio:  31
# Quote date:  2015-02-09 00:00:00 Average delta:  -0.558749808685914 New delta: -0.8921960164555394 Number of options in portfolio:  36
# Quote date:  2015-02-10 00:00:00 Average delta:  -0.5552348056993778 New delta: -0.4463794554204676 Number of options in portfolio:  22
# Quote date:  2015-02-11 00:00:00 Average delta:  -0.29788526361246154 New delta: 1.5157258077572535 Number of options in portfolio:  24
# Quote date:  2015-02-12 00:00:00 Average delta:  -0.5435628236446143 New delta: 0 Number of options in portfolio:  12
# Quote date:  2015-02-13 00:00:00 Average delta:  -0.004291750814869821 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-02-17 00:00:00 Average delta:  -0.636831642804066 New delta: -2.14192917685769 Number of options in portfolio:  26
# Quote date:  2015-02-18 00:00:00 Average delta:  -0.1876831369378808 New delta: 1.7447896901426607 Number of options in portfolio:  21
# Quote date:  2015-02-19 00:00:00 Average delta:  -0.29220338740497154 New delta: -1.390669816448898 Number of options in portfolio:  10
# Quote date:  2015-02-20 00:00:00 Average delta:  -0.5426285959652044 New delta: 0 Number of options in portfolio:  10
# Quote date:  2015-02-23 00:00:00 Average delta:  -0.6024864579977214 New delta: 0.9948570918919073 Number of options in portfolio:  19
# Quote date:  2015-02-24 00:00:00 Average delta:  -0.5783132722279695 New delta: 0.6269174576556736 Number of options in portfolio:  16
# Quote date:  2015-02-25 00:00:00 Average delta:  -0.6291083082244152 New delta: 0 Number of options in portfolio:  11
# Quote date:  2015-02-26 00:00:00 Average delta:  -0.6302919018020219 New delta: 0.34350658409385293 Number of options in portfolio:  13
# Quote date:  2015-02-27 00:00:00 Average delta:  -0.06376712545379586 New delta: 1.3919225908181267 Number of options in portfolio:  17
# Quote date:  2015-03-02 00:00:00 Average delta:  -0.4681706059275547 New delta: 0.570918375995093 Number of options in portfolio:  15
# Quote date:  2015-03-03 00:00:00 Average delta:  -0.3240315616020126 New delta: 1.6730677910651544 Number of options in portfolio:  14
# Quote date:  2015-03-04 00:00:00 Average delta:  -0.47925899815591905 New delta: 0.9462693119610603 Number of options in portfolio:  13
# Quote date:  2015-03-05 00:00:00 Average delta:  -0.4239460455342973 New delta: 1.5361713872340834 Number of options in portfolio:  20
# Quote date:  2015-03-06 00:00:00 Average delta:  -0.22621741267023363 New delta: 0.8621575807528667 Number of options in portfolio:  16
# Quote date:  2015-03-09 00:00:00 Average delta:  -0.5184920654823507 New delta: 0.7401115628019104 Number of options in portfolio:  18
# Quote date:  2015-03-10 00:00:00 Average delta:  -0.4483078096179708 New delta: 0.5828646487687983 Number of options in portfolio:  14
# Quote date:  2015-03-11 00:00:00 Average delta:  -0.06502602967997886 New delta: 1.4838404451766265 Number of options in portfolio:  10
# Quote date:  2015-03-12 00:00:00 Average delta:  -0.2127512843098515 New delta: 0.9975100012375048 Number of options in portfolio:  23
# Quote date:  2015-03-13 00:00:00 Average delta:  -0.0373956491242987 New delta: 0.629411636821223 Number of options in portfolio:  14
# Quote date:  2015-03-16 00:00:00 Average delta:  -0.2523573433485855 New delta: 0.6927786638698556 Number of options in portfolio:  17
# Quote date:  2015-03-17 00:00:00 Average delta:  -0.26691458473544544 New delta: 1.584685624713264 Number of options in portfolio:  16
# Quote date:  2015-03-18 00:00:00 Average delta:  -0.24484295636867956 New delta: 1.484327612096507 Number of options in portfolio:  16
# Quote date:  2015-03-19 00:00:00 Average delta:  -0.10207580482380355 New delta: 1.422683576262787 Number of options in portfolio:  13
# Quote date:  2015-03-20 00:00:00 Average delta:  -0.33231961308284963 New delta: 0.9137283423306486 Number of options in portfolio:  9
# Quote date:  2015-03-23 00:00:00 Average delta:  -0.4759555135399751 New delta: 0.5934411773030287 Number of options in portfolio:  15
# Quote date:  2015-03-24 00:00:00 Average delta:  -0.42122162079862396 New delta: 0.8361915300324578 Number of options in portfolio:  12
# Quote date:  2015-03-25 00:00:00 Average delta:  -0.10044872317685564 New delta: 0.6646039305179274 Number of options in portfolio:  10
# Quote date:  2015-03-26 00:00:00 Average delta:  -0.25061284214897156 New delta: 0.9741261461703151 Number of options in portfolio:  12
# Quote date:  2015-03-27 00:00:00 Average delta:  -0.11150187142332733 New delta: 0.9822868361868353 Number of options in portfolio:  7
# Quote date:  2015-03-30 00:00:00 Average delta:  -0.25738109736894504 New delta: 0.8369069938533362 Number of options in portfolio:  9
# Quote date:  2015-03-31 00:00:00 Average delta:  -0.09739006386041829 New delta: 0.9660332165565961 Number of options in portfolio:  11
# Quote date:  2015-04-01 00:00:00 Average delta:  -0.23086982389524546 New delta: 0.9354311030465887 Number of options in portfolio:  13
# Quote date:  2015-04-02 00:00:00 Average delta:  -0.17163563162483242 New delta: 0.3067310243524498 Number of options in portfolio:  10
# Quote date:  2015-04-06 00:00:00 Average delta:  -0.3980549380970302 New delta: 0.9512585006090167 Number of options in portfolio:  12
# Quote date:  2015-04-07 00:00:00 Average delta:  -0.5267745662531242 New delta: 0 Number of options in portfolio:  10
# Quote date:  2015-04-08 00:00:00 Average delta:  -0.29908231605106844 New delta: 0.8783174172639234 Number of options in portfolio:  15
# Quote date:  2015-04-09 00:00:00 Average delta:  -0.32785534236347513 New delta: 1.1685940355643987 Number of options in portfolio:  10
# Quote date:  2015-04-10 00:00:00 Average delta:  -0.23220009493493796 New delta: 0 Number of options in portfolio:  10
# Quote date:  2015-04-13 00:00:00 Average delta:  -0.2742094012397361 New delta: 0 Number of options in portfolio:  10
# Quote date:  2015-04-14 00:00:00 Average delta:  -0.46926690144652095 New delta: 0 Number of options in portfolio:  9
# Quote date:  2015-04-15 00:00:00 Average delta:  -0.221417136704802 New delta: 0.35281365990204444 Number of options in portfolio:  11
# Quote date:  2015-04-16 00:00:00 Average delta:  -0.7388312541684291 New delta: 0 Number of options in portfolio:  9
# Quote date:  2015-04-17 00:00:00 Average delta:  -0.7707067701722996 New delta: 0 Number of options in portfolio:  7
# Quote date:  2015-04-20 00:00:00 Average delta:  -0.3178785331024769 New delta: 1.3461941058114466 Number of options in portfolio:  12
# Quote date:  2015-04-21 00:00:00 Average delta:  -0.12062063640930833 New delta: 0.8347273482606894 Number of options in portfolio:  11
# Quote date:  2015-04-22 00:00:00 Average delta:  -0.4280103770248851 New delta: 0.9149081992129838 Number of options in portfolio:  17
# Quote date:  2015-04-23 00:00:00 Average delta:  -0.3549391293673143 New delta: 0.03183754759558394 Number of options in portfolio:  9
# Quote date:  2015-04-24 00:00:00 Average delta:  -0.6173835167298718 New delta: 0.8979673263793811 Number of options in portfolio:  10
# Quote date:  2015-04-27 00:00:00 Average delta:  -0.33263565389689503 New delta: 0.9863698753448354 Number of options in portfolio:  13
# Quote date:  2015-04-28 00:00:00 Average delta:  -0.3780077937774119 New delta: 0.9493060739795781 Number of options in portfolio:  10
# Quote date:  2015-04-29 00:00:00 Average delta:  -0.4342722544266554 New delta: 0.9994672979638765 Number of options in portfolio:  6
# Quote date:  2015-04-30 00:00:00 Average delta:  -0.5600471634430666 New delta: 0.9866596940886805 Number of options in portfolio:  17
# Quote date:  2015-05-01 00:00:00 Average delta:  -0.6247655004642014 New delta: 0.9930910748428627 Number of options in portfolio:  7
# Quote date:  2015-05-04 00:00:00 Average delta:  0.0629969506521694 New delta: 0.9849490466234461 Number of options in portfolio:  10
# Quote date:  2015-05-05 00:00:00 Average delta:  -0.2749070517582446 New delta: 0.9730506658479422 Number of options in portfolio:  13
# Quote date:  2015-05-06 00:00:00 Average delta:  -0.45671852518992573 New delta: 0.9759036049904282 Number of options in portfolio:  8
# Quote date:  2015-05-07 00:00:00 Average delta:  -0.1328984087171585 New delta: 0.3754892800148951 Number of options in portfolio:  10
# Quote date:  2015-05-08 00:00:00 Average delta:  -0.024211144508646452 New delta: 1.3372400314903434 Number of options in portfolio:  8
# Quote date:  2015-05-11 00:00:00 Average delta:  -0.19034042082484257 New delta: 0.9836506682177197 Number of options in portfolio:  10
# Quote date:  2015-05-12 00:00:00 Average delta:  0.10382559627837377 New delta: 0.9518190826440777 Number of options in portfolio:  13
# Quote date:  2015-05-13 00:00:00 Average delta:  -0.08628893973987146 New delta: 0.9910464788028988 Number of options in portfolio:  7
# Quote date:  2015-05-14 00:00:00 Average delta:  -0.26596188622290534 New delta: 0.880938070332724 Number of options in portfolio:  4
# Quote date:  2015-05-15 00:00:00 Average delta:  0.6147553457342207 New delta: 1.4625409884781295 Number of options in portfolio:  8
# Quote date:  2015-05-18 00:00:00 Average delta:  0.24538827689786147 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-05-19 00:00:00 Average delta:  -0.3533189903857893 New delta: 0 Number of options in portfolio:  7
# Quote date:  2015-05-20 00:00:00 Average delta:  0.41536639296412325 New delta: 0.8652749292058166 Number of options in portfolio:  8
# Quote date:  2015-05-21 00:00:00 Average delta:  -0.7623102636156756 New delta: 0 Number of options in portfolio:  5
# Quote date:  2015-05-22 00:00:00 Average delta:  0.4763991788459459 New delta: 1.793939050921933 Number of options in portfolio:  13
# Quote date:  2015-05-26 00:00:00 Average delta:  0.8294771886358882 New delta: 0 Number of options in portfolio:  1
# Quote date:  2015-05-27 00:00:00 Average delta:  0.6066936890395921 New delta: 0 Number of options in portfolio:  7
# Quote date:  2015-05-28 00:00:00 Average delta:  0.4413443217474116 New delta: 0 Number of options in portfolio:  5
# Quote date:  2015-05-29 00:00:00 Average delta:  -0.08354008883169493 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-06-01 00:00:00 Average delta:  0.43561244713884767 New delta: 0 Number of options in portfolio:  9
# Quote date:  2015-06-02 00:00:00 Average delta:  0.16367826033469068 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-06-03 00:00:00 Average delta:  0.04866808884586513 New delta: 0 Number of options in portfolio:  5
# Quote date:  2015-06-04 00:00:00 Average delta:  0.850135369994838 New delta: 0 Number of options in portfolio:  4
# Quote date:  2015-06-05 00:00:00 Average delta:  0.7102232224262524 New delta: 0 Number of options in portfolio:  3
# Quote date:  2015-06-08 00:00:00 Average delta:  0.03343118093144426 New delta: 0 Number of options in portfolio:  14
# Quote date:  2015-06-09 00:00:00 Average delta:  0.16180499326126874 New delta: 0.675057852399343 Number of options in portfolio:  9
# Quote date:  2015-06-10 00:00:00 Average delta:  -0.35839876951428495 New delta: 0.8925011822963236 Number of options in portfolio:  4
# Quote date:  2015-06-11 00:00:00 Average delta:  0.46300372413045593 New delta: 0 Number of options in portfolio:  7
# Quote date:  2015-06-12 00:00:00 Average delta:  0.4571955331721589 New delta: -1.833333333333317 Number of options in portfolio:  7
# Quote date:  2015-06-15 00:00:00 Average delta:  -0.24230599426526578 New delta: -0.5778194482023407 Number of options in portfolio:  6
# Quote date:  2015-06-16 00:00:00 Average delta:  -0.11175140053795987 New delta: 0.8299929685010079 Number of options in portfolio:  7
# Quote date:  2015-06-17 00:00:00 Average delta:  -0.1472417462008387 New delta: -0.5140490967927257 Number of options in portfolio:  5
# Quote date:  2015-06-18 00:00:00 Average delta:  -0.12042056005483318 New delta: 0.9999999999303258 Number of options in portfolio:  3
# Quote date:  2015-06-19 00:00:00 Average delta:  -0.4555943661527384 New delta: -2.283333328187955 Number of options in portfolio:  7
# Quote date:  2015-06-22 00:00:00 Average delta:  0.33542852514072435 New delta: 1.4736303383288036 Number of options in portfolio:  6
# Quote date:  2015-06-23 00:00:00 Average delta:  0.020990777777030088 New delta: 0 Number of options in portfolio:  10
# Quote date:  2015-06-24 00:00:00 Average delta:  0.3642689512971563 New delta: 0.9532024012731397 Number of options in portfolio:  4
# Quote date:  2015-06-25 00:00:00 Average delta:  -0.7898889397103289 New delta: 0 Number of options in portfolio:  3
# Quote date:  2015-06-26 00:00:00 Average delta:  0.6384608146874312 New delta: 0.997324189196078 Number of options in portfolio:  2
# Quote date:  2015-06-29 00:00:00 Average delta:  0.236679526443519 New delta: -0.8312650842685251 Number of options in portfolio:  5
# Quote date:  2015-06-30 00:00:00 Average delta:  -0.011029350423491735 New delta: -0.8080309968353074 Number of options in portfolio:  12
# Quote date:  2015-07-01 00:00:00 Average delta:  -0.4115589580457506 New delta: -1.6350154041249658 Number of options in portfolio:  12
# Quote date:  2015-07-02 00:00:00 Average delta:  -0.37614230164154383 New delta: 0 Number of options in portfolio:  4
# Quote date:  2015-07-06 00:00:00 Average delta:  -0.13716033567655386 New delta: 0.20474709858153306 Number of options in portfolio:  6
# Quote date:  2015-07-07 00:00:00 Average delta:  -0.3608839414492877 New delta: -1.4113215125903344 Number of options in portfolio:  14
# Quote date:  2015-07-08 00:00:00 Average delta:  -0.30365557989109426 New delta: 0 Number of options in portfolio:  7
# Quote date:  2015-07-09 00:00:00 Average delta:  0.033870512061488 New delta: 0 Number of options in portfolio:  8
# Quote date:  2015-07-10 00:00:00 Average delta:  -0.43518758312532674 New delta: -2.8744192471716308 Number of options in portfolio:  23
# Quote date:  2015-07-13 00:00:00 Average delta:  0.28647352814240185 New delta: 0.5361525351595138 Number of options in portfolio:  7
# Quote date:  2015-07-14 00:00:00 Average delta:  -0.4046172063309341 New delta: 0 Number of options in portfolio:  5
# Quote date:  2015-07-15 00:00:00 Average delta:  -0.29562279533649444 New delta: 0 Number of options in portfolio:  5
# Quote date:  2015-07-16 00:00:00 Average delta:  -0.12007061221664594 New delta: 0.9144154256792056 Number of options in portfolio:  5
# Quote date:  2015-07-17 00:00:00 Average delta:  -0.4470278111070766 New delta: 0.9736310216430404 Number of options in portfolio:  6
# Quote date:  2015-07-20 00:00:00 Average delta:  -0.00044295351989812975 New delta: 0.7295544561471862 Number of options in portfolio:  6
# Quote date:  2015-07-21 00:00:00 Average delta:  -0.08362597319756382 New delta: 0.874786082697935 Number of options in portfolio:  8
# Quote date:  2015-07-22 00:00:00 Average delta:  -0.4851187898690594 New delta: 0.8295356577855646 Number of options in portfolio:  11
# Quote date:  2015-07-23 00:00:00 Average delta:  -0.03409061103561333 New delta: 0.9909505921587924 Number of options in portfolio:  7
# Quote date:  2015-07-24 00:00:00 Average delta:  -0.5457985241640617 New delta: 0.4595645919047685 Number of options in portfolio:  9
# Quote date:  2015-07-27 00:00:00 Average delta:  0.37344514384547856 New delta: 0.9794205451298481 Number of options in portfolio:  4
# Quote date:  2015-07-28 00:00:00 Average delta:  -0.5710015161610487 New delta: 0 Number of options in portfolio:  2
# Quote date:  2015-07-29 00:00:00 Average delta:  0.031057633787480332 New delta: 0.9104053533640233 Number of options in portfolio:  8
# Quote date:  2015-07-30 00:00:00 Average delta:  0.5290049445759116 New delta: 0.9259013114181696 Number of options in portfolio:  7
# Quote date:  2015-07-31 00:00:00 Average delta:  -0.5798802665897469 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-08-03 00:00:00 Average delta:  0.5998329741581504 New delta: 0.8679742722643073 Number of options in portfolio:  3
# Quote date:  2015-08-04 00:00:00 Average delta:  0.28894929629506494 New delta: 0 Number of options in portfolio:  10
# Quote date:  2015-08-05 00:00:00 Average delta:  0.22037814754648152 New delta: 0 Number of options in portfolio:  10
# Quote date:  2015-08-06 00:00:00 Average delta:  0.32525925387753146 New delta: 0 Number of options in portfolio:  8
# Quote date:  2015-08-07 00:00:00 Average delta:  -0.2633931928601911 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-08-10 00:00:00 Average delta:  0.41834419326002253 New delta: 0.8791689530458391 Number of options in portfolio:  4
# Quote date:  2015-08-11 00:00:00 Average delta:  0.09371936503635214 New delta: 0 Number of options in portfolio:  4
# Quote date:  2015-08-12 00:00:00 Average delta:  0.38400149248148246 New delta: 0.8541499620338104 Number of options in portfolio:  9
# Quote date:  2015-08-13 00:00:00 Average delta:  0.27952728355037465 New delta: 0 Number of options in portfolio:  9
# Quote date:  2015-08-14 00:00:00 Average delta:  0.10855651517034272 New delta: 0 Number of options in portfolio:  4
# Quote date:  2015-08-17 00:00:00 Average delta:  0.5093004210246603 New delta: 0.9987342929557532 Number of options in portfolio:  6
# Quote date:  2015-08-18 00:00:00 Average delta:  0.6904295561634165 New delta: 0 Number of options in portfolio:  4
# Quote date:  2015-08-19 00:00:00 Average delta:  0.4846365445107684 New delta: 0 Number of options in portfolio:  3
# Quote date:  2015-08-20 00:00:00 Average delta:  1.3738108290528573e-06 New delta: 0 Number of options in portfolio:  1
# Quote date:  2015-08-21 00:00:00 Average delta:  -0.47893936689950944 New delta: -0.804018928426531 Number of options in portfolio:  9
# Quote date:  2015-08-24 00:00:00 Average delta:  -0.08340887772013686 New delta: 0.9401202379826119 Number of options in portfolio:  22
# Quote date:  2015-08-25 00:00:00 Average delta:  -0.05680122408705091 New delta: 0.8015196958192562 Number of options in portfolio:  11
# Quote date:  2015-08-26 00:00:00 Average delta:  -0.06299226752337961 New delta: 0.2397549683286856 Number of options in portfolio:  7
# Quote date:  2015-08-27 00:00:00 Average delta:  0.04072477441228904 New delta: 1.0 Number of options in portfolio:  9
# Quote date:  2015-08-28 00:00:00 Average delta:  -0.11491084836792198 New delta: 0.4407511217609889 Number of options in portfolio:  9
# Quote date:  2015-08-31 00:00:00 Average delta:  0.2766164424901944 New delta: 0.9400701957639267 Number of options in portfolio:  6
# Quote date:  2015-09-01 00:00:00 Average delta:  0.4101544196439556 New delta: 0 Number of options in portfolio:  2
# Quote date:  2015-09-02 00:00:00 Average delta:  0.44487618616342595 New delta: 0 Number of options in portfolio:  4
# Quote date:  2015-09-03 00:00:00 Average delta:  -0.08404049697880711 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-09-04 00:00:00 Average delta:  0.07611658892114934 New delta: 0.9701991865187093 Number of options in portfolio:  5
# Quote date:  2015-09-08 00:00:00 Average delta:  0.6027962538900399 New delta: 0.9235057223035844 Number of options in portfolio:  3
# Quote date:  2015-09-09 00:00:00 Average delta:  0.3373655547277942 New delta: 0 Number of options in portfolio:  4
# Quote date:  2015-09-10 00:00:00 Average delta:  0.06468454246799596 New delta: 0 Number of options in portfolio:  5
# Quote date:  2015-09-11 00:00:00 Average delta:  0.35531292203300874 New delta: 0.9993902577202918 Number of options in portfolio:  8
# Quote date:  2015-09-14 00:00:00 Average delta:  0.49231692524632825 New delta: 0 Number of options in portfolio:  7
# Quote date:  2015-09-15 00:00:00 Average delta:  0.18900209281188443 New delta: 0 Number of options in portfolio:  5
# Quote date:  2015-09-16 00:00:00 Average delta:  0.36676727198811154 New delta: 0.6045515719437297 Number of options in portfolio:  9
# Quote date:  2015-09-17 00:00:00 Average delta:  0.17923355568243615 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-09-18 00:00:00 Average delta:  0.14436816537891922 New delta: 0.9998290754046183 Number of options in portfolio:  8
# Quote date:  2015-09-21 00:00:00 Average delta:  0.1836560244965387 New delta: 0.9999839369685877 Number of options in portfolio:  6
# Quote date:  2015-09-22 00:00:00 Average delta:  0.14678681242954975 New delta: 0.24311242398296123 Number of options in portfolio:  7
# Quote date:  2015-09-23 00:00:00 Average delta:  0.5016328745699942 New delta: 0.9783034399804111 Number of options in portfolio:  6
# Quote date:  2015-09-24 00:00:00 Average delta:  0.14323709289532813 New delta: 0 Number of options in portfolio:  3
# Quote date:  2015-09-25 00:00:00 Average delta:  0.2248505386574725 New delta: 0.9937868055049099 Number of options in portfolio:  5
# Quote date:  2015-09-28 00:00:00 Average delta:  0.48323941270583526 New delta: 0 Number of options in portfolio:  4
# Quote date:  2015-09-29 00:00:00 Average delta:  -0.1524913298692854 New delta: 0 Number of options in portfolio:  8
# Quote date:  2015-09-30 00:00:00 Average delta:  0.654702897280479 New delta: 0.6487000641399477 Number of options in portfolio:  4
# Quote date:  2015-10-01 00:00:00 Average delta:  0.5508375248578169 New delta: -0.20390918375233985 Number of options in portfolio:  3
# Quote date:  2015-10-02 00:00:00 Average delta:  0.36657073060868467 New delta: -0.31628107802131433 Number of options in portfolio:  6
# Quote date:  2015-10-05 00:00:00 Average delta:  0.3253167912071726 New delta: -0.23484480947090947 Number of options in portfolio:  7
# Quote date:  2015-10-06 00:00:00 Average delta:  0.4134613964445389 New delta: -0.2214187016674699 Number of options in portfolio:  7
# Quote date:  2015-10-07 00:00:00 Average delta:  0.2759544198219253 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-10-08 00:00:00 Average delta:  0.14959586313394221 New delta: -0.2605088463727109 Number of options in portfolio:  3
# Quote date:  2015-10-09 00:00:00 Average delta:  0.3124470804687776 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-10-12 00:00:00 Average delta:  0.26935699146698583 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-10-13 00:00:00 Average delta:  0.5246472366704251 New delta: 0 Number of options in portfolio:  5
# Quote date:  2015-10-14 00:00:00 Average delta:  0.0521820595626766 New delta: 0 Number of options in portfolio:  2
# Quote date:  2015-10-15 00:00:00 Average delta:  0.23279638626412316 New delta: 0 Number of options in portfolio:  4
# Quote date:  2015-10-16 00:00:00 Average delta:  0.38289072773506566 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-10-19 00:00:00 Average delta:  0.8700774914447479 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-10-20 00:00:00 Average delta:  0.5699777935345346 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-10-21 00:00:00 Average delta:  0.6910232580326835 New delta: 0 Number of options in portfolio:  7
# Quote date:  2015-10-22 00:00:00 Average delta:  0.5910090989241128 New delta: 0 Number of options in portfolio:  4
# Quote date:  2015-10-23 00:00:00 Average delta:  0.8236419369443517 New delta: 0 Number of options in portfolio:  2
# Quote date:  2015-10-26 00:00:00 Average delta:  0.16144129326082007 New delta: -0.7595037717512301 Number of options in portfolio:  7
# Quote date:  2015-10-27 00:00:00 Average delta:  0.530806839868289 New delta: 0.9999775920669364 Number of options in portfolio:  5
# Quote date:  2015-10-28 00:00:00 Average delta:  0.34834083881036876 New delta: -0.6399555824831912 Number of options in portfolio:  5
# Quote date:  2015-10-29 00:00:00 Average delta:  -0.15709140297721064 New delta: -1.0102423780768124 Number of options in portfolio:  7
# Quote date:  2015-10-30 00:00:00 Average delta:  0.25741480014136997 New delta: 1.4777052391028886 Number of options in portfolio:  11
# Quote date:  2015-11-02 00:00:00 Average delta:  0.37755035240265034 New delta: 0 Number of options in portfolio:  4
# Quote date:  2015-11-03 00:00:00 Average delta:  0.24887929692005145 New delta: 0 Number of options in portfolio:  10
# Quote date:  2015-11-04 00:00:00 Average delta:  0.053258087896184476 New delta: -0.9205046735446288 Number of options in portfolio:  13
# Quote date:  2015-11-05 00:00:00 Average delta:  0.10751657646491022 New delta: 0.5160146237744636 Number of options in portfolio:  7
# Quote date:  2015-11-06 00:00:00 Average delta:  -0.0018745348318135616 New delta: 0.9834552474145754 Number of options in portfolio:  5
# Quote date:  2015-11-09 00:00:00 Average delta:  0.5248714878310999 New delta: 0.8556036414835734 Number of options in portfolio:  6
# Quote date:  2015-11-10 00:00:00 Average delta:  0.3342984543819139 New delta: 0 Number of options in portfolio:  5
# Quote date:  2015-11-11 00:00:00 Average delta:  0.001946801548330284 New delta: 0 Number of options in portfolio:  7
# Quote date:  2015-11-12 00:00:00 Average delta:  -0.09745484008294342 New delta: 0 Number of options in portfolio:  2
# Quote date:  2015-11-13 00:00:00 Average delta:  0.7311866761763582 New delta: 0.9996866822735474 Number of options in portfolio:  5
# Quote date:  2015-11-16 00:00:00 Average delta:  0.24004770446404092 New delta: -0.3955462593665755 Number of options in portfolio:  5
# Quote date:  2015-11-17 00:00:00 Average delta:  -0.2762448178517501 New delta: -0.9404898479732974 Number of options in portfolio:  9
# Quote date:  2015-11-18 00:00:00 Average delta:  0.667819044506723 New delta: 1.4898744021443253 Number of options in portfolio:  8
# Quote date:  2015-11-19 00:00:00 Average delta:  0.2153537687000229 New delta: -0.7116091350752889 Number of options in portfolio:  13
# Quote date:  2015-11-20 00:00:00 Average delta:  0.13197390331976402 New delta: 0 Number of options in portfolio:  7
# Quote date:  2015-11-23 00:00:00 Average delta:  0.04870363848281267 New delta: 0.9999999538719719 Number of options in portfolio:  3
# Quote date:  2015-11-24 00:00:00 Average delta:  0.08156081902470003 New delta: 0.9826491396284184 Number of options in portfolio:  8
# Quote date:  2015-11-25 00:00:00 Average delta:  0.2917147273970144 New delta: 0 Number of options in portfolio:  7
# Quote date:  2015-11-27 00:00:00 Average delta:  0.3232502959254547 New delta: -0.8287849580888562 Number of options in portfolio:  9
# Quote date:  2015-11-30 00:00:00 Average delta:  0.34888985106435966 New delta: -0.42781353153959845 Number of options in portfolio:  6
# Quote date:  2015-12-01 00:00:00 Average delta:  0.08964736041956829 New delta: 0 Number of options in portfolio:  6
# Quote date:  2015-12-02 00:00:00 Average delta:  -0.07353062523510707 New delta: -0.5722376910327123 Number of options in portfolio:  5
# Quote date:  2015-12-03 00:00:00 Average delta:  0.22188113363618728 New delta: -0.5122731670994858 Number of options in portfolio:  8
# Quote date:  2015-12-04 00:00:00 Average delta:  0.4520589213691239 New delta: 0 Number of options in portfolio:  1
# Quote date:  2015-12-07 00:00:00 Average delta:  -0.07232134143958266 New delta: 0 Number of options in portfolio:  7
# Quote date:  2015-12-08 00:00:00 Average delta:  0.04015719272425938 New delta: 0 Number of options in portfolio:  8
# Quote date:  2015-12-09 00:00:00 Average delta:  0.3023954122867478 New delta: 0.9994815844263348 Number of options in portfolio:  5
# Quote date:  2015-12-10 00:00:00 Average delta:  0.1999804699315815 New delta: -0.6448248166702215 Number of options in portfolio:  5
# Quote date:  2015-12-11 00:00:00 Average delta:  0.13370474906177304 New delta: -0.9344274356722032 Number of options in portfolio:  9
# Quote date:  2015-12-14 00:00:00 Average delta:  0.3571071949713479 New delta: 0.9999999999854853 Number of options in portfolio:  5
# Quote date:  2015-12-15 00:00:00 Average delta:  -0.23711553744099975 New delta: -0.4078875380786193 Number of options in portfolio:  6
# Quote date:  2015-12-16 00:00:00 Average delta:  -0.020447559480713362 New delta: 0 Number of options in portfolio:  3
# Quote date:  2015-12-17 00:00:00 Average delta:  0.08787243250200029 New delta: 0.9802122816633472 Number of options in portfolio:  9
# Quote date:  2015-12-18 00:00:00 Average delta:  0.16253456329225413 New delta: 0.7632205710129647 Number of options in portfolio:  4
# Quote date:  2015-12-21 00:00:00 Average delta:  0.11797823707514957 New delta: 0 Number of options in portfolio:  5
# Quote date:  2015-12-22 00:00:00 Average delta:  0.9706763061747186 New delta: 0 Number of options in portfolio:  2
# Quote date:  2015-12-23 00:00:00 Average delta:  0.32117504654022483 New delta: 0 Number of options in portfolio:  3
# Quote date:  2015-12-24 00:00:00 Average delta:  0.15384615384615385 New delta: 0 Number of options in portfolio:  0

# %%
print("Starting balance", starting_balance)
print("Ending balance", df['Balance'].iloc[-1])
print("Number of trades", df['Signal'].abs().sum())
profit = df['Balance'].iloc[-1] - starting_balance
print("Profit", profit)
print("Profit per trade", profit / df['Signal'].abs().sum())
print("Profit per day", profit / (df['Quote_date'].max() - df['Quote_date'].min()).days)
num_days = (df['Quote_date'].max() - df['Quote_date'].min()).days
print("Number of days", num_days)
cagr = (df['Total_value'].iloc[-1] / starting_balance) ** (365 / num_days) - 1
print("CAGR", cagr)
# Out:
# Starting balance 1000000
# Ending balance 938299.1599999984
# Number of trades 11779
# Profit -61700.8400000016
# Profit per trade -5.238206978521233
# Profit per day -173.3169662921393
# Number of days 356
# CAGR -0.060863882944846126

# %% [markdown]
# ### Analysis

# %%
import matplotlib.pyplot as plt

def plot(df):
    # Just keep one row per Quote_date, and that should be the last row
    df = df.groupby('Quote_date').last()
    plt.plot(df['Total_value'], label='Total value')
    plt.plot(df['Balance'], label='Balance')
    plt.plot(df['Options_value'], label='Options value')
    plt.title('Portfolio value over time')
    # Set x-axis major ticks to weekly interval, on Mondays
    ax = plt.gca()
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()

# %%
plot(df)

# %%
import numpy as np

# Calculate the sharpe ratio of the strategy using the daily returns and using df["R"] as the annualised risk-free rate
def sharpe_ratio(df):
    df["Daily_returns"] = df["Total_value"].pct_change()
    sharpe_ratio = np.sqrt(252) * ((df["Daily_returns"].mean() - (df["R"]/252).mean()) / df["Daily_returns"].std())
    return sharpe_ratio


# Calculate max drawdown
def max_drawdown(df):
    df["Drawdown"] = df["Total_value"] / df["Total_value"].cummax() - 1
    max_drawdown = df["Drawdown"].min()
    return max_drawdown
# Out:
# Sharpe ratio -0.12025924048304085
# Max drawdown -0.07511953990870046

# %% [markdown]
# ### Finding best thresholds

# %%
# Test many conbinations of sell and buy thresholds to find the one that gives the highest Sharpe ratio
def find_best_thresholds(df, starting_balance):
    best_sharpe = -100
    best_sell = 0
    best_buy = 0
    for sell in range(5, 25, 5):
        for buy in range(5, 25, 5):
            df = df_read.copy()
            buy_signal, sell_signal = generate_buy_sell_signals(df, buy, sell)
            df = trader(df, buy_signal, sell_signal, starting_balance)
            df = calculate_options_value(df)
            sharpe = sharpe_ratio(df)
            # Print and plot the results
            print("Buy threshold", buy, "Sell threshold", sell, "Sharpe ratio", sharpe)
            print("Starting balance", starting_balance, "Ending balance", df['Balance'].iloc[-1])
            print("Anualiased return", (df['Balance'].iloc[-1] / starting_balance - 1) * 252 / len(df))
            print("Sharpe: ", sharpe)
            plot(df)
            if sharpe > best_sharpe:
                best_sharpe = sharpe
                best_sell = sell
                best_buy = buy
    return best_sharpe, best_sell, best_buy

best_sharpe, best_sell, best_buy = find_best_thresholds(df_read, starting_balance)
print("Best Sharpe ratio", best_sharpe, "Best sell threshold", best_sell, "Best buy threshold", best_buy)
