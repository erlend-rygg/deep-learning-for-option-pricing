# %% [markdown]
# ### Imports

# %%
import pandas as pd
import datetime
import os
import sys
import math
import matplotlib.pyplot as plt
import numpy as np
import warnings
from pandas.errors import SettingWithCopyWarning
import dask.dataframe as dd


warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)

# %% [markdown]
# ### Parameters

# %%
google_colab = False

# %% [markdown]
# ### Data loading

# %%
# Set the path to the root directory
path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
# Read dataframes using Dask
df = dd.read_csv(path + '/data/predictions/03.06_Combined_results.csv')
df_ba = dd.read_csv(path + '/data/processed_data/2011_11feb-2023mar_NSS_filtered_vF_wo_moneyness_filtering_B_A.csv')
df["Quote_date"] = dd.to_datetime(df["Quote_date"])
df_ba["Quote_date"] = dd.to_datetime(df_ba["Quote_date"])


df = df[df['Quote_date'] >= '2015-01-11']
df_ba = df_ba[df_ba['Quote_date'] >= '2015-01-11']

# In df, rename IV to BS-IV
df = df.rename(columns={"IV": "BS-IV"})
# In df_ba, drop

# %%
df = df_ba.merge(df, on=["Quote_date", "TTM", "Strike"], how="inner", suffixes=("", "_drop"))

# %% [markdown]
# ### Data processing

# %%
# Turning the dask dataframe into a pandas dataframe
df = df.compute()

# %%
# Drop the columns that were duplicated
df = df.drop(columns=["Unnamed: 0", "Underlying_last_drop", "R_drop"])

# %%
display(df)
# Out:
#        Quote_date Expire_date    Price     Bid     Ask  Underlying_last
# 0      2021-10-28  2021-11-22     2.40     2.3     2.5          4596.06  \
# 1      2021-10-28  2021-11-24   471.15   465.1   477.2          4596.06
# 2      2021-10-28  2021-11-24   447.35   441.3   453.4          4596.06
# 3      2021-10-28  2021-11-24   278.95   277.6   280.3          4596.06
# 4      2021-10-28  2021-11-24    27.90    27.6    28.2          4596.06
# ...           ...         ...      ...     ...     ...              ...
# 276384 2023-03-31  2024-06-21  1023.55  1016.8  1030.3          4109.88
# 276385 2023-03-31  2024-06-21   441.05   439.4   442.7          4109.88
# 276386 2023-03-31  2024-06-21   378.75   377.1   380.4          4109.88
# 276387 2023-03-31  2024-06-21   241.50   240.2   242.8          4109.88
# 276388 2023-03-31  2024-12-20  1404.30  1387.7  1420.9          4109.88
#
#         Strike       TTM    Delta       IV  ...  Unnamed: 0_drop
# 0       4770.0  0.068493  0.05234  0.09040  ...          8024770  \
# 1       4125.0  0.073973  0.97148  0.22757  ...          8024830
# 2       4150.0  0.073973  0.96024  0.23055  ...          8024833
# 3       4330.0  0.073973  0.86316  0.20684  ...          8024855
# 4       4655.0  0.073973  0.31650  0.11015  ...          8024919
# ...        ...       ...      ...      ...  ...              ...
# 276384  3300.0  1.227397  0.83766  0.25839  ...         10539408
# 276385  4100.0  1.227397  0.60836  0.20096  ...         10539440
# 276386  4200.0  1.227397  0.56651  0.19304  ...         10539444
# 276387  4450.0  1.227397  0.44877  0.17343  ...         10539452
# 276388  2900.0  1.726027  0.86500  0.29032  ...         10539463
#
#                                    Option_ID Price_drop
# 0       2021-11-22 00:00:00.000000000-4770.0       2.40  \
# 1       2021-11-24 00:00:00.000000000-4125.0     471.15
# 2       2021-11-24 00:00:00.000000000-4150.0     447.35
# 3       2021-11-24 00:00:00.000000000-4330.0     278.95
# 4       2021-11-24 00:00:00.000000000-4655.0      27.90
# ...                                      ...        ...
# 276384  2024-06-21 00:00:00.000000008-3300.0    1023.55
# 276385  2024-06-21 00:00:00.000000008-4100.0     441.05
# 276386  2024-06-21 00:00:00.000000008-4200.0     378.75
# 276387  2024-06-21 00:00:00.000000008-4450.0     241.50
# 276388  2024-12-20 00:00:00.000000000-2900.0    1404.30
#
#                           Expiry_date      Rolling        GARCH        BS-IV
# 0       2021-11-22 00:00:00.000000000    14.081819     3.731827    32.459923  \
# 1       2021-11-24 00:00:00.000000000   471.356773   471.243560   472.982939
# 2       2021-11-24 00:00:00.000000000   446.436876   446.245529   448.610653
# 3       2021-11-24 00:00:00.000000000   270.579322   266.718558   281.597490
# 4       2021-11-24 00:00:00.000000000    44.978175    24.666053    71.101789
# ...                               ...          ...          ...          ...
# 276384  2024-06-21 00:00:00.000000008  1011.429569   999.079034  1013.919792
# 276385  2024-06-21 00:00:00.000000008   436.190941   393.773176   443.319286
# 276386  2024-06-21 00:00:00.000000008   383.643065   339.205866   391.068229
# 276387  2024-06-21 00:00:00.000000008   272.306342   226.177016   280.003432
# 276388  2024-12-20 00:00:00.000000000  1422.426678  1416.219514  1423.839865
#
#              Heston          MLP     LSTM-MLP
# 0         16.602708     3.063117     0.000000
# 1        483.403958   497.956120   472.454200
# 2        459.295221   474.198600   448.179100
# 3        291.291243   298.791870   275.611360
# 4         59.286527    25.695774    14.938367
# ...             ...          ...          ...
# 276384  1023.155752  1026.013800  1054.239500
# 276385   443.870558   445.750240   495.669250
# 276386   385.906237   383.547600   436.614650
# 276387   258.122649   249.474870   307.278440
# 276388  1391.410100  1416.434200  1433.491600
#
# [10514930 rows x 21 columns]

# %%
# Dates
df["TTM"] = (df["TTM"] * 365).astype(int)
df['Expiry_date'] = pd.to_datetime(df['Expire_date'])
df.drop(columns=["Expire_date"], axis=1, inplace=True)
df['Quote_date'] = pd.to_datetime(df['Quote_date'])

# Adding option ID
df["Option_ID"] = df["Expiry_date"].astype(str) + "-" + df["Strike"].astype(str)

# Period to be traded on
df = df[(df["Expiry_date"] >= "2015-01-01") & (df["Expiry_date"] <= "2023-03-31")]
df = df[(df["Quote_date"] >= "2015-01-01") & (df["Quote_date"] <= "2023-03-31")]

# %% [markdown]
# Create underlying dict

# %%
# Create dict with Quote_date as key and Underlying_last as key
underlying_last_dict = df.groupby("Quote_date")["Underlying_last"].mean().to_dict()

# %% [markdown]
# Adding TTM=0 row

# %%
def add_row(group):
    last_row = group.iloc[-1]
    expiry_date = last_row['Expiry_date']

    # If underlying_last_dict[expiry_date] is not defined, return None
    if expiry_date not in underlying_last_dict:
        print("Marked option for deletion: " + str(last_row['Option_ID']) + " on date: " + str(last_row['Quote_date']) + " due to missing underlying price.")
        return None

    underlying_last_on_expiry = underlying_last_dict[expiry_date]
    intrinsic_value = np.maximum(underlying_last_on_expiry - last_row['Strike'], 0)

    new_row = last_row.copy()
    new_row['Quote_date'] = expiry_date
    new_row['Expiry_date'] = expiry_date
    new_row['TTM'] = 0
    new_row['Underlying_last'] = underlying_last_on_expiry
    new_row['Price'] = intrinsic_value

    return new_row

# %%
df = df.sort_values(['Quote_date', 'Expiry_date'])

# %%
new_rows = df.groupby("Option_ID").apply(add_row).reset_index(drop=True)
# Out:
# Marked option for deletion: 2017-09-27-1500.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1600.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1650.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1700.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1750.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1800.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1850.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1900.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1950.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-1975.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2000.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2025.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2050.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2075.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2100.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2110.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2120.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2125.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2130.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2140.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2150.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2160.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2170.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2175.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2180.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2190.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2200.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2205.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2210.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2215.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2220.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2225.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2230.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2235.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2240.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2245.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2250.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2255.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2260.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2265.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2270.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2275.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2280.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2285.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2290.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2295.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2300.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2305.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2310.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2315.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2320.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2325.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2330.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2335.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2340.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2345.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2350.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2355.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2360.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2365.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2370.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2375.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2380.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2385.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2390.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2395.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2400.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2405.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2410.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2415.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2420.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2425.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2430.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2435.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2440.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2445.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2450.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2455.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2460.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2465.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2470.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2475.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2480.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2485.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2490.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2495.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2500.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2505.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2510.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2515.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2520.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2525.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2530.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2535.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2540.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2545.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2550.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2555.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2560.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2565.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2570.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2575.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2580.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2585.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2590.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2595.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2600.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2605.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2610.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2615.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2620.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2625.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2650.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2700.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2750.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2017-09-27-2800.0 on date: 2017-09-26 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1300.0 on date: 2019-01-14 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1350.0 on date: 2019-01-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1400.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1450.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1500.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1550.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1600.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1650.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1700.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1750.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1800.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1850.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1875.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1900.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1925.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1950.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-1975.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2000.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2010.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2020.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2025.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2030.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2040.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2050.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2060.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2070.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2075.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2080.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2090.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2100.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2110.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2120.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2125.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2130.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2140.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2150.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2160.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2170.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2175.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2180.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2190.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2200.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2205.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2210.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2215.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2220.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2225.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2230.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2235.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2240.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2245.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2250.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2255.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2260.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2265.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2270.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2275.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2280.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2285.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2290.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2295.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2300.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2305.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2310.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2315.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2320.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2325.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2330.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2335.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2340.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2345.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2350.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2355.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2360.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2365.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2370.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2375.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2380.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2385.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2390.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2395.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2400.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2405.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2410.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2415.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2420.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2425.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2430.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2435.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2440.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2445.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2450.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2455.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2460.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2465.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2470.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2475.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2480.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2485.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2490.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2495.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2500.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2505.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2510.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2515.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2520.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2525.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2530.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2535.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2540.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2545.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2550.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2555.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2560.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2565.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2570.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2575.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2580.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2585.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2590.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2595.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2600.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2605.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2610.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2615.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2620.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2625.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2630.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2635.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2640.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2645.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2650.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2655.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2660.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2665.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2670.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2675.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2680.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2685.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2690.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2695.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2700.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2705.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2710.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2715.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2720.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2725.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2730.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2735.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2740.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2745.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2750.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2755.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2760.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2765.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2770.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2775.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2780.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2785.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2790.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2795.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2800.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2805.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2810.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2815.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2820.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2825.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2830.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2835.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2840.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2845.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2850.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2855.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2860.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2865.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2870.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2875.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2880.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2885.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2890.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2895.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2900.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2905.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2910.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2915.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2920.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2925.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2930.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2935.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2940.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2945.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2950.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2955.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2960.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2965.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2970.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2975.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2980.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2985.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2990.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-2995.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3000.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3005.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3010.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3015.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3020.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3025.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3030.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3050.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3075.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3100.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3150.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3200.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3250.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3300.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3350.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-03-01-3400.0 on date: 2019-02-28 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-1700.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-1800.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-1850.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-1900.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-1950.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2000.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2050.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2100.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2150.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2200.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2250.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2275.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2300.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2325.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2350.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2375.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2390.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2400.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2410.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2420.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2425.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2430.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2440.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2450.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2460.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2470.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2475.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2480.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2490.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2500.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2510.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2520.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2525.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2530.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2535.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2540.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2545.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2550.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2555.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2560.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2565.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2570.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2575.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2580.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2585.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2590.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2595.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2600.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2605.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2610.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2615.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2620.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2625.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2630.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2635.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2640.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2645.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2650.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2655.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2660.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2665.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2670.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2675.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2680.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2685.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2690.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2695.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2700.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2705.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2710.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2715.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2720.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2725.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2730.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2735.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2740.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2745.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2750.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2755.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2760.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2765.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2770.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2775.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2780.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2785.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2790.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2795.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2800.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2805.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2810.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2815.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2820.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2825.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2830.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2835.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2840.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2845.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2850.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2855.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2860.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2865.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2870.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2875.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2880.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2885.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2890.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2895.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2900.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2905.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2910.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2019-04-17-2915.0 on date: 2019-04-16 00:00:00 due to missing underlying price.
# ...
# Marked option for deletion: 2023-03-31-3930.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3935.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3940.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3945.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3950.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3955.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3960.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3965.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3970.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3975.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3980.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3985.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3990.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-3995.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4000.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4005.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4010.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4015.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4020.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4025.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4030.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4035.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4040.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4045.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4050.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4055.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4060.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4065.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4070.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4075.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4080.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4085.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4090.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4095.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4100.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4105.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4110.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4115.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4120.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4125.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4130.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4135.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4140.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4145.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4150.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4155.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4160.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4165.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4170.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4175.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4180.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4185.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4190.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4195.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4200.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4205.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4210.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4215.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4220.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4225.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4230.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4235.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4240.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4245.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4250.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4255.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4260.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4265.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4270.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4275.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4280.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4285.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4290.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4295.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4300.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4305.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4310.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4315.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4320.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4325.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4330.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4335.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4340.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4345.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4350.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4355.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4360.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4365.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4370.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4375.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4380.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4385.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4390.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4395.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4400.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4405.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4410.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4415.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4420.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4425.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4430.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4440.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4450.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4460.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4470.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4475.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4480.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4490.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4500.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4510.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4520.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4525.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4530.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4540.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4550.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4560.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4570.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4575.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4580.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4590.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4600.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4625.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4650.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4675.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4700.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4725.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4750.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4775.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4800.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4825.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4850.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4875.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4900.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4925.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4950.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-4975.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5000.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5025.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5050.0 on date: 2023-03-30 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5100.0 on date: 2023-02-16 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5150.0 on date: 2023-02-15 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5200.0 on date: 2023-02-07 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5250.0 on date: 2022-08-19 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5300.0 on date: 2022-08-18 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5400.0 on date: 2022-04-21 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5500.0 on date: 2022-04-20 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5600.0 on date: 2022-04-08 00:00:00 due to missing underlying price.
# Marked option for deletion: 2023-03-31-5700.0 on date: 2022-04-04 00:00:00 due to missing underlying price.

# %%
new_rows = new_rows.dropna()

# %%
# Concatenate the original df with the new rows
df = pd.concat([df, new_rows], axis=0)

# %%
# Write to csv
df.to_csv(path + '/data/trading/Full trading data - All models - wo missing-filtering.csv', index=False)
